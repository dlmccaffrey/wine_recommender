# %% [markdown]
# # Exploring the API provided by wine.com
#
# Documentation: https://api.wine.com/wiki
#
# According to the documentation, the API contains detailed information on the wines, as well as professional ratings and community reviews. In this notebook, I just want to explore the API capabilities and the data returned.

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# There are two RESTful APIs that will be helpful: the Catalog and the Category APIs. The Catalog allows you to search through all the wine data. The Category allows you to search through the categories displayed in the Catalog.

# %% [markdown]
# First, lets look at the Catalog. The following query returns all red wines from the wine finder, starting at record #11, with a list size of 5 products:

# %%
#read the API key from config.py
creds={}
with open('config.py') as file:
    exec(file.read(), creds)
garbage = creds.pop('__builtins__')

# %%
url_string = "http://services.wine.com/api/beta2/service.svc/json/catalog"

# %%
payload = {'filter': 'categories(490+124)', 'offset': '10', 'size': '5', 'apikey': creds['KEY']}

# %%
r= requests.get(url_string, params=payload)

# %%
data = json.loads(r.text)

# %%
data.keys()
# Out:
# dict_keys(['Status', 'Products'])

# %%
data['Products'].keys()
# Out:
# dict_keys(['Offset', 'Url', 'Total', 'List'])

# %% [markdown]
# Individual wines are stored in the 'List' key of the 'Products' dictionary. This returns a list of the wines. The documentation for the data on the wines is here: https://api.wine.com/wiki/api-object-dictionary#_catalog_objects

# %%
data['Products']['List'][0]
# Out:
# {'Appellation': {'Id': 2398,
#   'Name': 'Napa Valley',
#   'Region': {'Area': None,
#    'Id': 101,
#    'Name': 'California',
#    'Url': 'http://www.wine.com/v6/California/wine/list.aspx?N=7155+101'},
#   'Url': 'http://www.wine.com/v6/Napa-Valley/wine/list.aspx?N=7155+101+2398'},
#  'Community': {'Reviews': {'HighestScore': 0,
#    'List': [],
#    'Url': 'http://www.wine.com/v6/Pahlmeyer-Napa-Valley-Proprietary-Red-2013/wine/142049/Detail.aspx?pageType=reviews'},
#   'Url': 'http://www.wine.com/v6/Pahlmeyer-Napa-Valley-Proprietary-Red-2013/wine/142049/Detail.aspx'},
#  'Description': '',
#  'GeoLocation': {'Latitude': -360,
#   'Longitude': -360,
#   'Url': 'http://www.wine.com/v6/aboutwine/mapof.aspx?winery=3636'},
#  'Id': 142049,
#  'Labels': [{'Id': '142049m',
#    'Name': 'thumbnail',
#    'Url': 'http://cache.wine.com/labels/142049m.jpg'}],
#  'Name': 'Pahlmeyer Napa Valley Proprietary Red 2013',
#  'PriceMax': 159.99,
#  'PriceMin': 155.0,
#  'PriceRetail': 175.0,
#  'ProductAttributes': [{'Id': 36,
#    'ImageUrl': 'http://cache.wine.com/assets/glo_icon_collectable_big.gif',
#    'Name': 'Collectible Wines',
#    'Url': 'http://www.wine.com/v6/Collectible-Wines/wine/list.aspx?N=7155+36'},
#   {'Id': 613,
#    'ImageUrl': '',
#    'Name': 'Big &amp; Bold',
#    'Url': 'http://www.wine.com/v6/Big-andamp-Bold/wine/list.aspx?N=7155+613'},
#   {'Id': 0, 'ImageUrl': '', 'Name': 'Has Large Label', 'Url': ''}],
#  'Ratings': {'HighestScore': 96, 'List': []},
#  'Retail': None,
#  'Type': 'Wine',
#  'Url': 'http://www.wine.com/v6/Pahlmeyer-Napa-Valley-Proprietary-Red-2013/wine/142049/Detail.aspx',
#  'Varietal': {'Id': 144,
#   'Name': 'Bordeaux Red Blends',
#   'Url': 'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144',
#   'WineType': {'Id': 124,
#    'Name': 'Red Wines',
#    'Url': 'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'}},
#  'Vineyard': {'GeoLocation': {'Latitude': -360,
#    'Longitude': -360,
#    'Url': 'http://www.wine.com/v6/aboutwine/mapof.aspx?winery=3636'},
#   'Id': 7270,
#   'ImageUrl': 'http://cache.wine.com/aboutwine/basics/images/winerypics/3636.jpg',
#   'Name': 'Pahlmeyer',
#   'Url': 'http://www.wine.com/v6/Pahlmeyer/learnabout.aspx?winery=3636'},
#  'Vintage': '2013',
#  'Vintages': {'List': []}}

# %% [markdown]
# There is a lot of data that I don't have access to at the moment, but I should be able to gain access just by asking. We'll see if that happens. In the mean time, I'll see what I can do now.

# %% [markdown]
# Data to extract from each 'List' element:
# * ['Id'] - Id of the wine. Will be helpful for future searches.
# * ['Name'] - Name of the wine.
# * ['Vineyard']['Id'] - Id of the vineyard/winery.
# * ['Vineyard']['Name'] - Name of the vineyard/winery.
# * ['Appellation']['Id'] - Id of the appellation.
# * ['Appellation']['Name'] - Name of the appellation. These are well defined geographical regions.
# * ['Appellation']['Region']['Id'] - Id of the region.
# * ['Appellation']['Region']['Name'] - Name of the region. It is a higher level location. For example, when the appellation is Napa Valley, the region is California.
# * ['Appellation']['Region']['Area']['Id'] - Id of the area. Can be null.
# * ['Appellation']['Region']['Area']['Name'] - Name of the area. This would be htings like France. Can be null. It is null for region == California.
#     * The whole key called 'Area' could be null -> gives a TypeError if you try to access it.
# * ['Varietal']['Id'] - Id of the varietal. Useful for searching.
# * ['Varietal']['Name'] - Name of the varietal.
# * ['Varietal']['Url'] - The URL for other wines of the same varietal. Can be used as a GET query.
# * ['Varietal']['WineType'] - A higher level classification, e.g. red wine. Also has Id, Name, and Url.
# * ['Ratings']['HighestScore'] - The highest score given by a professional rater. Only have this for now.
# * ['Vintage'] - The vintage.

# %%
data['Products']['List'][4]['Vintage']
# Out:
# '2012'

# %% [markdown]
# For things like the Varietal Url, it is probably better to have all of the categories and just reference the Ids in the main data table. I will test out the Category API for this purpose.

# %%
payload_cat = {'filter': 'categories(490)', 'apikey': creds['KEY']}

# %%
url_string_cat = "http://services.wine.com/api/beta2/service.svc/json/categorymap"

# %%
r_cat = requests.get(url_string_cat, params=payload_cat)

# %%
data_cat = json.loads(r_cat.text)

# %%
data_cat.keys()
# Out:
# dict_keys(['Categories', 'Status'])

# %% [markdown]
# The Categories key holds a list.

# %%
data_cat['Categories'][1]['Name']
# Out:
# 'Varietal'

# %% [markdown]
# It seems that the URLs are all blank in the Categories object, so I think I will just create the databases myself from the Catalog data. Scheme:
# * main_wines_db: the main wine database
#     * 'Wine ID': ['Id']
#     * 'Wine name': ['Name']
#     * 'Vintage': ['Vintage']
#     * 'Score': ['Ratings']['HighestScore']
#     * 'Vineyard ID': ['Vineyard']['Id']
#     * 'Varietal ID': ['Varietal']['Id']
#     * 'Wine Type ID': ['Varietal']['WineType']['Id']
#     * 'Appellation ID': ['Appellation']['Id']
#     * 'Region ID': ['Appellation']['Region']['Id']
#     * 'Area ID': ['Appellation']['Region']['Area']['Id']
#
# * varietals_db: the database of varietals
#     * 'Varietal ID': ['Varietal']['Id']
#     * 'Varietal Name': ['Varietal']['Name']
#     * 'Varietal URL': ['Varietal']['Url']
#
# * wine_types_db: the database of wine types
#     * 'Wine Type ID': ['WineType']['Id']
#     * 'Wine Type Name': ['WineType']['Name']
#     * 'Wine Type URL': ['WineType']['Url']
#
# * appellations_db: the database of regions
#     * 'Appellation ID': ['Appellation']['Id']
#     * 'Appellation Name': ['Appellation']['Name']
#
# * regions_db: the database of regions
#     * 'Region ID': ['Appellation']['Region']['Id']
#     * 'Region Name': ['Appellation']['Region']['Name']
#
# * areas_db: the database of areas
#     * 'Area ID': ['Appellation']['Region']['Area']['Id']
#     * 'Area Name': ['Appellation']['Region']['Area']['Name']
#
# * vineyards_db: the database of vineyards/wineries
#     * 'Vineyard ID': ['Vineyard']['Id']
#     * 'Vineyard Name': ['Vineyard']['Name']

# %%
payload['size'] = 100

# %%
r2 = requests.get(url_string, params=payload)

# %%
data2 = json.loads(r2.text)

# %%
data2['Status']['ReturnCode']
# Out:
# 0

# %% [markdown]
# Since I might be able to get access to Category data later, I won't handle duplicates yet.

# %%
main_wines = []
varietals = []
wine_types = []
appellations = []
regions = []
locations = []
areas = []

for item in data2['Products']['List']:
    #get the data for main_wine
    wine = [item['Id'],
            item['Name'],
            item['Vintage'],
            item['Ratings']['HighestScore'],
            item['Vineyard']['Id'],
            item['Varietal']['Id'],
            item['Varietal']['WineType']['Id'],
            item['Appellation']['Id'],
            item['Appellation']['Region']['Id']]
    
    #handle area since it can be None
    try:
        area = item['Appellation']['Region']['Area']['Id']
    except TypeError:
        area = None
    
    #add area
    wine.append(area)
    
    #append to main_wine
    main_wines.append(wine)
    
    #get the data for varietals
    varietal = [item['Varietal']['Id'],
                 item['Varietal']['Name'],
                 item['Varietal']['Url']]
    
    #append to varietals
    varietals.append(varietal)
    
    #get the data for wine_types
    wine_type = [item['Varietal']['WineType']['Id'],
                 item['Varietal']['WineType']['Name'],
                 item['Varietal']['WineType']['Url']]
    
    #append to wine_types
    wine_types.append(wine_type)
    
    #get the data for appellations
    appellation = [item['Appellation']['Id'],
                item['Appellation']['Name']]
    
    #append to appellations
    appellations.append(appellation)
    
    #get the data for regions
    region = [item['Appellation']['Region']['Id'],
              item['Appellation']['Region']['Name']]
    
    #append to regions
    regions.append(region)
    
    #try to get data for areas
    try:
        area = [item['Appellation']['Region']['Area']['Id'],
                item['Appellation']['Region']['Area']['Name']]
    except TypeError:
        pass
    else:
        areas.append(area) #only do this if try works
    
    #get the data for vineyards
    vineyard = [item['Vineyard']['Id'], item['Vineyard']['Name']]
    
    #append to vineyards
    vineyards.append(vineyard)

# %%
main_wines
# Out:
# [[142049,
#   'Pahlmeyer Napa Valley Proprietary Red 2013',
#   '2013',
#   96,
#   7270,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [153157,
#   'Silver Oak Napa Valley Cabernet Sauvignon 2011',
#   '2011',
#   91,
#   7396,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [154691,
#   'Haras de Pirque Hussonet Gran Reserva Cabernet Sauvignon 2011',
#   '2011',
#   95,
#   6024,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [155466,
#   'Joseph Phelps Insignia 2013',
#   '2013',
#   100,
#   8881,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [158048,
#   'The Debate Three Vineyard Collection 3-pack 2012',
#   '2012',
#   100,
#   999997220,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [162035, 'Verite La Joie 2013', '2013', 100, 8509, 144, 124, 2371, 101, None],
#  [103730,
#   'Chateau Lafite Rothschild  2008',
#   '2008',
#   98,
#   999999160,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [154233,
#   'Caymus Special Selection Cabernet Sauvignon 2013',
#   '2013',
#   95,
#   8626,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [143695,
#   'Moss Roxx Ancient Vine Zinfandel 2013',
#   '2013',
#   0,
#   999997365,
#   141,
#   124,
#   2388,
#   101,
#   None],
#  [158817,
#   'Caymus Napa Valley Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   8626,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [159424,
#   'Duckhorn Napa Valley Cabernet Sauvignon 2013',
#   '2013',
#   93,
#   8808,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [6372,
#   'Chateau Latour  2000',
#   '2000',
#   100,
#   999999028,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [160512,
#   'Silver Oak Alexander Valley Cabernet Sauvignon 2012',
#   '2012',
#   90,
#   999998522,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [146301,
#   'Tenuta Sette Ponti Oreno 2013',
#   '2013',
#   97,
#   5616,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [142069,
#   'Fattoria dei Barbi Brunello di Montalcino 2010',
#   '2010',
#   96,
#   7746,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [147347,
#   'Freemark Abbey Napa Valley Cabernet Sauvignon 2012',
#   '2012',
#   93,
#   8798,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [121291,
#   'Carruades de Lafite  2010',
#   '2010',
#   95,
#   999999692,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [150748,
#   'La Rioja Alta Gran Reserva 904 Tinto 2005',
#   '2005',
#   96,
#   8220,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [121312,
#   'Chateau Duhart-Milon  2010',
#   '2010',
#   96,
#   999999127,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [159480,
#   'Beaux Freres The Beaux Freres Vineyard Pinot Noir 2014',
#   '2014',
#   95,
#   8693,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [123798,
#   'Chateau Petrus  2010',
#   '2010',
#   100,
#   999999170,
#   144,
#   124,
#   10043,
#   10038,
#   None],
#  [138240,
#   'Antinori Guado al Tasso 2011',
#   '2011',
#   95,
#   8966,
#   144,
#   124,
#   2452,
#   105,
#   None],
#  [148375,
#   'Canvasback Red Mountain Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   999996940,
#   139,
#   124,
#   2052,
#   104,
#   None],
#  [152182,
#   'Nickel & Nickel Sullenger Vineyard Cabernet Sauvignon 2013',
#   '2013',
#   96,
#   8623,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [162038, 'Verite La Muse 2013', '2013', 100, 8509, 138, 124, 2371, 101, None],
#  [158886,
#   'Oakville Winery Estate Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   999997962,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [146929,
#   'Clarendon Hills Astralis Syrah 2010',
#   '2010',
#   100,
#   8382,
#   146,
#   124,
#   9063,
#   108,
#   None],
#  [154475,
#   'Jamieson Ranch Vineyards Double Lariat Cabernet Sauvignon 2014',
#   '2014',
#   93,
#   999996814,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [121437,
#   'Chateau Montrose  2010',
#   '2010',
#   100,
#   999999167,
#   144,
#   124,
#   10044,
#   10038,
#   None],
#  [153921,
#   'Hahn Winery Santa Lucia Highlands Pinot Noir 2014',
#   '2014',
#   92,
#   8341,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [150956,
#   'Caymus Napa Valley Cabernet Sauvignon (1.5 Liter Magnum) 2013',
#   '2013',
#   94,
#   8626,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [154706,
#   'Jordan Cabernet Sauvignon 2012',
#   '2012',
#   90,
#   8485,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [162198,
#   'Benanti Rosso Di Verzella Etna Rosso 2014',
#   '2014',
#   94,
#   999998509,
#   145,
#   124,
#   10066,
#   105,
#   None],
#  [6277,
#   'Chateau Petrus  1983',
#   '1983',
#   93,
#   999999170,
#   144,
#   124,
#   10043,
#   10038,
#   None],
#  [162797,
#   'Bibi Graetz Testamatta 2012',
#   '2012',
#   95,
#   999998003,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [153464,
#   'Chateau Petrus (Futures Pre-Sale) 2015',
#   '2015',
#   100,
#   999999170,
#   144,
#   124,
#   10043,
#   10038,
#   None],
#  [162037, 'Verite Le Desir 2013', '2013', 99, 8509, 144, 124, 2371, 101, None],
#  [122383,
#   'Chateau Pontet-Canet  2010',
#   '2010',
#   100,
#   5917,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [94129,
#   "Chateau Cos d'Estournel  2005",
#   '2005',
#   99,
#   999999130,
#   144,
#   124,
#   10044,
#   10038,
#   None],
#  [153461,
#   'Chateau Lafite Rothschild (Futures Pre-Sale) 2015',
#   '2015',
#   98,
#   999999160,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [131554,
#   "Tenuta dell'Ornellaia  2012",
#   '2012',
#   97,
#   7837,
#   144,
#   124,
#   2452,
#   105,
#   None],
#  [147735,
#   'Mt. Brave Cabernet Sauvignon 2012',
#   '2012',
#   92,
#   999997859,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [161485,
#   'Clos du Val Cabernet Sauvignon (1.5 Liter Magnum) 2013',
#   '2013',
#   95,
#   8469,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [161616,
#   'Robert Mondavi Reserve Cabernet Sauvignon 2013',
#   '2013',
#   96,
#   8844,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [140319,
#   'Joseph Phelps Insignia 2012',
#   '2012',
#   97,
#   8881,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [136332,
#   'Chateau Lafleur  2010',
#   '2010',
#   100,
#   999999159,
#   144,
#   124,
#   10043,
#   10038,
#   None],
#  [121427,
#   'Chateau Lynch-Bages  2010',
#   '2010',
#   98,
#   999999161,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [78665,
#   'Chateau Mouton Rothschild  1995',
#   '1995',
#   95,
#   999999169,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [146925,
#   'Chateau Peymouton  2012',
#   '2012',
#   92,
#   999995860,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [157511,
#   'CVNE Gran Reserva 2010',
#   '2010',
#   94,
#   8101,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [144717,
#   'Greywacke Pinot Noir 2013',
#   '2013',
#   96,
#   999998220,
#   143,
#   124,
#   10071,
#   114,
#   None],
#  [163145,
#   'The Prisoner Wine Company The Prisoner 2015',
#   '2015',
#   0,
#   999997499,
#   145,
#   124,
#   2398,
#   101,
#   None],
#  [148901,
#   'Schug Sonoma Coast Pinot Noir 2014',
#   '2014',
#   93,
#   8008,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [151284,
#   'Castello di Monsanto Chianti Classico Riserva 2012',
#   '2012',
#   93,
#   8210,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [138995,
#   'Gaja Rennina Brunello di Montalcino 2010',
#   '2010',
#   97,
#   8061,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [123372,
#   'Chateau Pavie  2010',
#   '2010',
#   100,
#   999999171,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [149938,
#   'Clos du Val Cabernet Sauvignon 2013',
#   '2013',
#   95,
#   8469,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [157488,
#   "Frog's Leap Zinfandel 2014",
#   '2014',
#   94,
#   8794,
#   141,
#   124,
#   2398,
#   101,
#   None],
#  [151206,
#   'Joel Gott Blend No. 815 Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   6048,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [134614,
#   'Chateau Mayne Vieil  2011',
#   '2011',
#   91,
#   999996970,
#   144,
#   124,
#   10047,
#   10038,
#   None],
#  [144406,
#   'Borgo Scopeto Chianti Classico 2013',
#   '2013',
#   91,
#   8231,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [128618,
#   'Lucky Proprietary Red Blend',
#   'Non-Vintage',
#   0,
#   999997909,
#   145,
#   124,
#   2416,
#   101,
#   None],
#  [163536,
#   'Antica Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   999998771,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [159497,
#   'Vieux Chateau Certan (Futures Pre-Sale) 2015',
#   '2015',
#   100,
#   6554,
#   144,
#   124,
#   10043,
#   10038,
#   None],
#  [139162,
#   'Gaja Sugarille Brunello di Montalcino 2010',
#   '2010',
#   97,
#   8061,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [124681,
#   'Tenuta Sette Ponti Oreno 2011',
#   '2011',
#   96,
#   5616,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [142506,
#   'Frescobaldi Castelgiocondo Brunello di Montalcino 2010',
#   '2010',
#   97,
#   8894,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [161058,
#   'Robert Stemmler Anderson Valley Pinot Noir 2013',
#   '2013',
#   93,
#   6449,
#   143,
#   124,
#   2416,
#   101,
#   None],
#  [153601,
#   'Clos des Papes Chateauneuf-du-Pape 2014',
#   '2014',
#   95,
#   6396,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [138834,
#   "Trombetta Gap's Crown Vineyard Pinot Noir 2012",
#   '2012',
#   95,
#   999996787,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [149668,
#   'Chapter 24 Last Chapter Pinot Noir 2013',
#   '2013',
#   94,
#   999996819,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [155704,
#   'Rombauer Zinfandel 2014',
#   '2014',
#   91,
#   8337,
#   141,
#   124,
#   2288,
#   101,
#   None],
#  [162936,
#   "Frog's Leap Estate Grown Cabernet Sauvignon (1.5 Liter Magnum) 2014",
#   '2014',
#   93,
#   8794,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [154969,
#   'Faust Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   5997,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [162969,
#   'Haras de Pirque Hussonet Gran Reserva Cabernet Sauvignon 2012',
#   '2012',
#   92,
#   6024,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [144686,
#   'Baron de Ley Reserva 2010',
#   '2010',
#   95,
#   999996026,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [160520,
#   'Concha y Toro Don Melchor Cabernet Sauvignon 2012',
#   '2012',
#   98,
#   8963,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [152181,
#   'Kendall-Jackson Grand Reserve Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   8788,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [143049,
#   "Tenuta dell'Ornellaia (3 Liter) 2012",
#   '2012',
#   97,
#   7837,
#   144,
#   124,
#   2452,
#   105,
#   None],
#  [146923,
#   'Clarendon Hills Liandra Syrah 2010',
#   '2010',
#   95,
#   8382,
#   146,
#   124,
#   9063,
#   108,
#   None],
#  [152377,
#   'Il Poggione Brunello di Montalcino Riserva Vigna Paganelli 2010',
#   '2010',
#   98,
#   7372,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [156558,
#   "Stag's Leap Wine Cellars S.L.V. Cabernet Sauvignon 2013",
#   '2013',
#   96,
#   8754,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [153518,
#   'Domaine Drouhin Oregon Pinot Noir 2014',
#   '2014',
#   92,
#   8233,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [160280,
#   'CADE Reserve Cabernet Sauvignon 2013',
#   '2013',
#   97,
#   999998393,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [152437,
#   'Roots Run Deep Educated Guess Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   999999478,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [151946,
#   'Bodegas Muga Gran Reserva Prado Enea (1.5 Liter Magnum) 2006',
#   '2006',
#   98,
#   8660,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [163085,
#   'Chappellet Pritchard Hill Estate Vineyard Cabernet Sauvignon 2013',
#   '2013',
#   98,
#   8677,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [151599,
#   'Miura Vineyards Silacci Vineyard Pinot Noir 2010',
#   '2010',
#   0,
#   5370,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [136918,
#   'Bodegas Muga Seleccion Especial Reserva 2010',
#   '2010',
#   96,
#   8660,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [152847,
#   'CADE Estate Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   999998393,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [131677,
#   'Meo-Camuzet Clos de Vougeot Grand Cru Pres le Cellier 2009',
#   '2009',
#   94,
#   7069,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [152403,
#   "Stags' Leap Winery Cabernet Sauvignon 2013",
#   '2013',
#   94,
#   8834,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [89263,
#   "Stag's Leap Wine Cellars Fay Vineyard Cabernet Sauvignon 2012",
#   '2012',
#   96,
#   8754,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [143368,
#   'Black Stallion Winery Estate Cabernet Sauvignon 2013',
#   '2013',
#   93,
#   999998126,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [146047,
#   'Donatella Cinelli Colombini Brunello di Montalcino 2010',
#   '2010',
#   94,
#   999999768,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [145313,
#   'Treana Red Blend 2013',
#   '2013',
#   91,
#   6307,
#   145,
#   124,
#   2462,
#   101,
#   None],
#  [154216,
#   'Felsina Berardenga Chianti Classico 2013',
#   '2013',
#   92,
#   5257,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [143286,
#   'Flowers Sea View Ridge Pinot Noir 2012',
#   '2012',
#   94,
#   5388,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [154689,
#   'Rafael Reverte Odipus Grenache 2008',
#   '2008',
#   91,
#   999997354,
#   10080,
#   124,
#   9065,
#   109,
#   None],
#  [159247,
#   'Felsina Berardenga Chianti Classico Riserva 2012',
#   '2012',
#   95,
#   5257,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [152022,
#   'Seghesio Sonoma Zinfandel 2014',
#   '2014',
#   93,
#   8762,
#   141,
#   124,
#   2371,
#   101,
#   None],
#  [138811,
#   'Benjamin Romeo Contador 2010',
#   '2010',
#   96,
#   5714,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [160077,
#   'Mendel Unus 2011',
#   '2011',
#   93,
#   999999704,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [154261,
#   'Smith & Hook Cabernet Sauvignon 2014',
#   '2014',
#   90,
#   6623,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [162739, 'Col Solare  2013', '2013', 94, 8491, 144, 124, 2414, 104, None],
#  [163733, 'Masseto  2013', '2013', 98, 999994608, 138, 124, 2452, 105, None],
#  [157551,
#   'K Vintners The Creator 2013',
#   '2013',
#   96,
#   999999718,
#   145,
#   124,
#   1956,
#   104,
#   None],
#  [130091,
#   'Faustino I Gran Reserva 2001',
#   '2001',
#   98,
#   8777,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [143594,
#   'Le Potazzine Gorelli Brunello di Montalcino 2010',
#   '2010',
#   94,
#   999996198,
#   163,
#   124,
#   2309,
#   105,
#   None],
#  [160288,
#   'Renzo Marinai Gran Selezione Chianti Classico 2010',
#   '2010',
#   97,
#   999994832,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [158899,
#   'Chateau Mayne Vieil Cuvee Alienor 2013',
#   '2013',
#   91,
#   999996970,
#   138,
#   124,
#   10047,
#   10038,
#   None],
#  [162921,
#   'William Harrison Rutherford Cabernet Sauvignon 2012',
#   '2012',
#   0,
#   999996472,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [142802,
#   'Chateau Cheval Blanc (Futures Pre-Sale) 2014',
#   '2014',
#   99,
#   999999153,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [151602,
#   'Klinker Brick Old Vine Zinfandel 2013',
#   '2013',
#   94,
#   999999528,
#   141,
#   124,
#   2388,
#   101,
#   None],
#  [145703,
#   'La Gerla Brunello di Montalcino (375ML half-bottle) 2010',
#   '2010',
#   95,
#   8299,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [154316,
#   'M. Chapoutier Le Pavillon Ermitage 2009',
#   '2009',
#   100,
#   8857,
#   146,
#   124,
#   10055,
#   10039,
#   None],
#  [152746,
#   'Columbia Crest Grand Estates Red Blend 2012',
#   '2012',
#   90,
#   8853,
#   145,
#   124,
#   2414,
#   104,
#   None],
#  [160663,
#   'Meiomi Pinot Noir 2015',
#   '2015',
#   0,
#   999997417,
#   143,
#   124,
#   2388,
#   101,
#   None],
#  [159769,
#   'Frank Family Vineyards Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   9711,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [150064,
#   'Robert Hall Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   999998277,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [159725,
#   'Far Niente Cabernet Sauvignon (1.5 Liter Magnum) 2013',
#   '2013',
#   94,
#   8634,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [163245,
#   'Orin Swift Cellars Abstract 2015',
#   '2015',
#   0,
#   999996953,
#   145,
#   124,
#   2388,
#   101,
#   None],
#  [146835,
#   'Chateau Les-Charmes Godard  2012',
#   '2012',
#   90,
#   7763,
#   144,
#   124,
#   2263,
#   10038,
#   None],
#  [161998,
#   'Domaine Saint Prefert Isabel Ferrando Chateauneuf-du-Pape Colombis 2014',
#   '2014',
#   94,
#   10026,
#   10080,
#   124,
#   2375,
#   10039,
#   None],
#  [155539,
#   'Ghost Block Oakville Estate Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   999999529,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [149320,
#   'Inglenook CASK Cabernet Sauvignon 2012',
#   '2012',
#   93,
#   6169,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [159956,
#   'Intrinsic Cabernet Sauvignon 2014',
#   '2014',
#   92,
#   999994845,
#   139,
#   124,
#   2414,
#   104,
#   None],
#  [161873,
#   'Ridge Lytton Springs 2014',
#   '2014',
#   96,
#   8345,
#   145,
#   124,
#   2371,
#   101,
#   None],
#  [158579,
#   'Adelsheim Pinot Noir 2014',
#   '2014',
#   92,
#   8716,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [151539,
#   'Barnett Vineyards Rattlesnake Cabernet Sauvignon 2013',
#   '2013',
#   98,
#   7071,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [160558,
#   'Abadia Retuerta Seleccion Especial 2012',
#   '2012',
#   93,
#   8662,
#   169,
#   124,
#   9067,
#   109,
#   None],
#  [157161,
#   'Cakebread Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   8518,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [122451,
#   'Chateau Margaux  2010',
#   '2010',
#   100,
#   999999164,
#   144,
#   124,
#   10040,
#   10038,
#   None],
#  [158965,
#   'Caymus Napa Valley Cabernet Sauvignon (1.5 Liter Magnum) 2014',
#   '2014',
#   0,
#   8626,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [150733,
#   'Joseph Phelps Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   8881,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [154620,
#   'Sur de los Andes Malbec Reserva 2012',
#   '2012',
#   90,
#   999998208,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [149191,
#   'Groth Reserve Cabernet Sauvignon 2012',
#   '2012',
#   96,
#   8887,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [131981,
#   "Bernardus Garys' Vineyard Pinot Noir 2011",
#   '2011',
#   92,
#   8705,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [154673,
#   'Chateau La Cardonne Medoc 2009',
#   '2009',
#   92,
#   8035,
#   144,
#   124,
#   10041,
#   10038,
#   None],
#  [163903,
#   'Atlas Peak Napa Valley Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   8575,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [150342, 'CVNE Crianza 2012', '2012', 91, 8101, 169, 124, 2370, 109, None],
#  [153460,
#   'Chateau Mouton Rothschild (Futures Pre-Sale) 2015',
#   '2015',
#   99,
#   999999169,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [154069,
#   'Substance Cabernet Sauvignon 2014',
#   '2014',
#   91,
#   999999678,
#   139,
#   124,
#   2414,
#   104,
#   None],
#  [42791,
#   'Chateau Pichon-Longueville Baron  2000',
#   '2000',
#   97,
#   999999173,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [160874,
#   'G.D. Vajra Barolo Albe 2012',
#   '2012',
#   0,
#   8407,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [145334,
#   'Joseph Phelps Freestone Vineyards Sonoma Coast Pinot Noir 2013',
#   '2013',
#   93,
#   8881,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [155307, 'Almaviva Red 2013', '2013', 97, 8070, 144, 124, 2428, 112, None],
#  [154014,
#   'Domus Aurea Cabernet Sauvignon 2011',
#   '2011',
#   96,
#   7960,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [160475,
#   'Farnetella Chianti Colli Senesi 2013',
#   '2013',
#   92,
#   999994818,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [136260,
#   'Domaine de Cristia Cuvee Renaissance Chateauneuf-du-Pape 2010',
#   '2010',
#   96,
#   999998601,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [146919,
#   'Clarendon Hills Sandown Cabernet Sauvignon 2010',
#   '2010',
#   95,
#   8382,
#   139,
#   124,
#   9063,
#   108,
#   None],
#  [139846,
#   'Lapostolle Cuvee Alexandre Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   8759,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [153612,
#   'Xavier Vins Chateauneuf du Pape La Reserve VII IX X',
#   'Non-Vintage',
#   96,
#   999995114,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [94325,
#   'Chateau Clerc Milon  2005',
#   '2005',
#   95,
#   999999131,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [155024,
#   'Chateau Montelena Estate Cabernet Sauvignon 2012',
#   '2012',
#   95,
#   5916,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [146881,
#   'Shafer Hillside Select Cabernet Sauvignon 2011',
#   '2011',
#   96,
#   6191,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [140226,
#   'Ritual Casablanca Valley Pinot Noir 2014',
#   '2014',
#   93,
#   999998234,
#   143,
#   124,
#   2428,
#   112,
#   None],
#  [152242,
#   'Mount Veeder Winery Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   999999037,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [150892,
#   'CVNE Imperial Reserva Rioja 2010',
#   '2010',
#   93,
#   8101,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [163720,
#   'Department 66 Grenache Cotes Catalan 2013',
#   '2013',
#   95,
#   999996113,
#   10080,
#   124,
#   2374,
#   102,
#   None],
#  [158835,
#   'Jean-Louis Chave Hermitage 2013',
#   '2013',
#   97,
#   8534,
#   146,
#   124,
#   10055,
#   10039,
#   None],
#  [160935,
#   'Seghesio Cortina Zinfandel 2013',
#   '2013',
#   94,
#   8762,
#   141,
#   124,
#   2371,
#   101,
#   None],
#  [142877,
#   'Chateau Pichon-Longueville Baron (Futures Pre-Sale) 2014',
#   '2014',
#   96,
#   999999173,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [145756,
#   'Guigal Chateauneuf-du-Pape 2010',
#   '2010',
#   93,
#   8657,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [154066,
#   'Caparzo Brunello di Montalcino 2011',
#   '2011',
#   94,
#   8225,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [159551,
#   'Produttori del Barbaresco Barbaresco (1.5 Liter Magnum) 2011',
#   '2011',
#   93,
#   7847,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [163098,
#   'Hall Kathryn Hall Cabernet Sauvignon (375ML half-bottle) 2013',
#   '2013',
#   100,
#   6019,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [145306,
#   'Reata Three County Pinot Noir 2013',
#   '2013',
#   90,
#   999997585,
#   143,
#   124,
#   2388,
#   101,
#   None],
#  [158132,
#   'Franciscan Estate Merlot 2013',
#   '2013',
#   0,
#   8800,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [157960,
#   'Chateau le Doyenne  2011',
#   '2011',
#   91,
#   999995136,
#   144,
#   124,
#   2263,
#   10038,
#   None],
#  [155885,
#   'Noiro Santa Lucia Highlands Pinot Noir 2013',
#   '2013',
#   0,
#   999996570,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [151731,
#   'Produttori del Barbaresco Barbaresco 2012',
#   '2012',
#   93,
#   7847,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [132842,
#   'Domenico Clerico Barolo Pajana 2009',
#   '2009',
#   95,
#   999998938,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [141673,
#   'Yalumba The Scribbler 2012',
#   '2012',
#   95,
#   8728,
#   145,
#   124,
#   9058,
#   108,
#   None],
#  [158784,
#   'Tikal Natural Organic Red Blend 2013',
#   '2013',
#   94,
#   6351,
#   145,
#   124,
#   2089,
#   112,
#   None],
#  [152261,
#   'Giacomo Mori Chianti 2013',
#   '2013',
#   92,
#   6562,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [147062,
#   'MooBuzz Monterey Pinot Noir 2013',
#   '2013',
#   92,
#   999999578,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [143580,
#   'Guigal La Landonne Cote Rotie 2011',
#   '2011',
#   99,
#   8657,
#   146,
#   124,
#   10053,
#   10039,
#   None],
#  [121850,
#   'Sella & Mosca Cannonau di Sardegna Riserva 2011',
#   '2011',
#   0,
#   6359,
#   10080,
#   124,
#   10068,
#   105,
#   None],
#  [143546,
#   'J. Bookwalter Conflict Conner-Lee Vineyard 2012',
#   '2012',
#   94,
#   8503,
#   145,
#   124,
#   2052,
#   104,
#   None],
#  [144300,
#   'Belle Glos Las Alturas Vineyard Pinot Noir 2014',
#   '2014',
#   90,
#   8176,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [152520,
#   'Valdicava Brunello Riserva Madonna del Piano 2010',
#   '2010',
#   100,
#   6998,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [159834,
#   'The Donum Estate Russian River Valley Pinot Noir 2013',
#   '2013',
#   95,
#   999999649,
#   143,
#   124,
#   1863,
#   101,
#   None],
#  [152617,
#   'Lucienne Lone Oak Vineyard Pinot Noir 2013',
#   '2013',
#   92,
#   999998723,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [136560,
#   'Ringbolt Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   6403,
#   139,
#   124,
#   9062,
#   108,
#   None],
#  [135816,
#   'DAOU Vineyards Reserve Cabernet Sauvignon 2013',
#   '2013',
#   93,
#   999997989,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [133805,
#   'Domaine Ponsot Corton Cuvee du Bourdon Grand Cru 2011',
#   '2011',
#   93,
#   10660,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [162958,
#   'Orin Swift Cellars Mercury Head Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   999996953,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [153268,
#   'Chateau Montelena Napa Valley Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   5916,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [147831,
#   'The Prisoner Wine Company Cuttings 2013',
#   '2013',
#   91,
#   999997499,
#   145,
#   124,
#   2398,
#   101,
#   None],
#  [157651,
#   'Tenuta Sette Ponti Crognolo 2014',
#   '2014',
#   93,
#   5616,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [94393,
#   'Chateau Pape Clement  2005',
#   '2005',
#   99,
#   999999165,
#   144,
#   124,
#   10051,
#   10038,
#   None],
#  [152058,
#   'Decoy Sonoma County Pinot Noir 2014',
#   '2014',
#   90,
#   999998524,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [146026,
#   'Beringer Private Reserve Cabernet Sauvignon 2012',
#   '2012',
#   96,
#   8866,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [158729,
#   'G.D. Vajra Barolo Albe 2011',
#   '2011',
#   93,
#   8407,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [161657,
#   'Diamond Creek Red Rock Terrace Cabernet Sauvignon 2013',
#   '2013',
#   97,
#   8527,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [121955,
#   "Chateau L'Evangile  2010",
#   '2010',
#   98,
#   999999045,
#   144,
#   124,
#   10043,
#   10038,
#   None],
#  [153697,
#   'Nickel & Nickel C.C. Ranch Cabernet Sauvignon 2013',
#   '2013',
#   95,
#   8623,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [155886,
#   'Scarecrow Cabernet Sauvignon 2013',
#   '2013',
#   100,
#   999999035,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [156900,
#   'Condado de Haza Ribera del Duero Tinto 2012',
#   '2012',
#   93,
#   8934,
#   169,
#   124,
#   9067,
#   109,
#   None],
#  [152532, 'Zenato Amarone 2011', '2011', 94, 8285, 195, 124, 2352, 105, None],
#  [154823,
#   'Calera Mt. Harlan Ryan Vineyard Pinot Noir 2013',
#   '2013',
#   95,
#   8816,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [99244,
#   'Le Macchiole Paleo 2005',
#   '2005',
#   95,
#   7906,
#   197,
#   124,
#   2452,
#   105,
#   None],
#  [163086,
#   'Paul Hobbs Beckstoffer To Kalon Vineyard Cabernet Sauvignon 2013',
#   '2013',
#   100,
#   8348,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [147344,
#   'Marques de Murrieta Castillo Ygay Gran Reserva 2007',
#   '2007',
#   98,
#   8951,
#   145,
#   124,
#   2370,
#   109,
#   None],
#  [148440,
#   'Domaine Drouhin Oregon Laurene Pinot Noir 2012',
#   '2012',
#   93,
#   8233,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [160335,
#   'Duckhorn Napa Valley Cabernet Sauvignon (1.5 Liter Magnum) 2013',
#   '2013',
#   93,
#   8808,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [155542,
#   'Goldeneye Anderson Valley Pinot Noir 2013',
#   '2013',
#   91,
#   6436,
#   143,
#   124,
#   2416,
#   101,
#   None],
#  [137383,
#   'Monteverro  2010',
#   '2010',
#   97,
#   999996743,
#   144,
#   124,
#   2452,
#   105,
#   None],
#  [138894,
#   'Chateau Baret  2010',
#   '2010',
#   91,
#   999996929,
#   144,
#   124,
#   10051,
#   10038,
#   None],
#  [162719,
#   'Flying Goat Cellars Dierberg Vineyard Pinot Noir 2012',
#   '2012',
#   94,
#   999996206,
#   143,
#   124,
#   2124,
#   101,
#   None],
#  [145812,
#   'Hourglass Blueline Cabernet Sauvignon 2011',
#   '2011',
#   91,
#   999998321,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [149148, 'Gaja Barbaresco 2012', '2012', 94, 8061, 170, 124, 2431, 105, None],
#  [123296,
#   'Cayuse Bionic Frog Syrah 2008',
#   '2008',
#   100,
#   5773,
#   146,
#   124,
#   1956,
#   104,
#   None],
#  [144182,
#   'Leeuwin Estate Art Series Shiraz 2012',
#   '2012',
#   92,
#   8656,
#   146,
#   124,
#   9062,
#   108,
#   None],
#  [156325,
#   'Locations by Dave Phinney I-2',
#   'Non-Vintage',
#   90,
#   999997130,
#   145,
#   124,
#   2309,
#   105,
#   None],
#  [148875,
#   'La Rioja Alta Vina Ardanza Reserva 2007',
#   '2007',
#   94,
#   8220,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [158947,
#   'Dominus Napanook Vineyard 2013',
#   '2013',
#   97,
#   8073,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [155583,
#   'Flowers Sonoma Coast Pinot Noir 2014',
#   '2014',
#   90,
#   5388,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [163016,
#   'William Harrison Estate Cabernet Franc 2012',
#   '2012',
#   0,
#   999996472,
#   197,
#   124,
#   2398,
#   101,
#   None],
#  [141258, 'Leviathan  2012', '2012', 92, 999998295, 145, 124, 2416, 101, None],
#  [163337, 'Luca Malbec 2014', '2014', 93, 8095, 10079, 124, 2089, 112, None],
#  [131259,
#   'Chateau Teyssier  2011',
#   '2011',
#   90,
#   8143,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [123860,
#   'Cayuse Bionic Frog Syrah 2004',
#   '2004',
#   99,
#   5773,
#   146,
#   124,
#   1956,
#   104,
#   None],
#  [152461,
#   'Stoller Vineyards Reserve Pinot Noir 2012',
#   '2012',
#   93,
#   999998917,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [154212,
#   'Ramey Pedregal Vineyard Cabernet Sauvignon 2012',
#   '2012',
#   97,
#   999999757,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [161898,
#   'Daniel Cohn Bellacosa Cabernet Sauvignon 2014',
#   '2014',
#   94,
#   999994725,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [148207,
#   'Chimney Rock Stags Leap District Cabernet Sauvignon (375ML) 2012',
#   '2012',
#   94,
#   7449,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [157652,
#   'Yangarra Estate McLaren Vale Shiraz 2013',
#   '2013',
#   96,
#   6257,
#   146,
#   124,
#   9063,
#   108,
#   None],
#  [144070,
#   'Chateau Hanteillan Haut Medoc (Futures Pre-Sale) 2014',
#   '2014',
#   93,
#   999995988,
#   144,
#   124,
#   10041,
#   10038,
#   None],
#  [154674,
#   'Castiglion del Bosco Brunello di Montalcino 2011',
#   '2011',
#   92,
#   9728,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [149722,
#   'Marcelo Pelleriti Reserve Malbec 2012',
#   '2012',
#   93,
#   999995410,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [154310,
#   'St. Francis Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   8784,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [161888,
#   'Robert Mondavi Reserve Cabernet Sauvignon (1.5 Liter Magnum) 2009',
#   '2009',
#   95,
#   8844,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [159535,
#   'Goldeneye Anderson Valley Pinot Noir (375ML half-bottle) 2013',
#   '2013',
#   91,
#   6436,
#   143,
#   124,
#   2416,
#   101,
#   None],
#  [138805,
#   'St. Supery Elu Red Meritage 2012',
#   '2012',
#   94,
#   8699,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [146817,
#   'Beringer Knights Valley Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   8866,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [150924,
#   'Carmen Gran Reserva Cabernet Sauvignon 2012',
#   '2012',
#   91,
#   7839,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [152062,
#   'Saxum James Berry Vineyard 2013',
#   '2013',
#   100,
#   999999524,
#   10082,
#   124,
#   2462,
#   101,
#   None],
#  [159004, 'Bogle Phantom 2013', '2013', 0, 8820, 145, 124, 2388, 101, None],
#  [150594,
#   'Penner-Ash Willamette Valley Pinot Noir 2013',
#   '2013',
#   90,
#   999999661,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [143540,
#   'Chateau Grand-Puy-Lacoste (Futures Pre-Sale) 2014',
#   '2014',
#   96,
#   999999156,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [156174,
#   'J Vineyards Russian River Pinot Noir 2014',
#   '2014',
#   0,
#   999998889,
#   143,
#   124,
#   1863,
#   101,
#   None],
#  [106891,
#   'Chateau Montelena Estate Cabernet Sauvignon 2006',
#   '2006',
#   93,
#   5916,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [133802,
#   'Domaine Ponsot Corton-Bressandes Grand Cru 2011',
#   '2011',
#   94,
#   10660,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [150589,
#   'Rex Hill Willamette Valley Pinot Noir 2013',
#   '2013',
#   90,
#   8493,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [149824,
#   'Ventana Rubystone Red 2014',
#   '2014',
#   91,
#   9802,
#   10082,
#   124,
#   2462,
#   101,
#   None],
#  [150251,
#   'Hess Collection Mount Veeder Cabernet Sauvignon 2012',
#   '2012',
#   94,
#   8629,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [162491,
#   'M. Marengo Barolo Bricco Viole 2012',
#   '2012',
#   96,
#   999999608,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [146257,
#   'Noble Vines 337 Lodi Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   999996904,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [144420,
#   'Bodegas Ateca Honoro Vera Garnacha 2014',
#   '2014',
#   90,
#   999999760,
#   10080,
#   124,
#   9065,
#   109,
#   None],
#  [151864,
#   'Beaulieu Vineyard Coastal Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   8907,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [149459,
#   'Michael David Winery Freakshow Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   999999918,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [127576,
#   'Chateau Pavie Macquin  2005',
#   '2005',
#   96,
#   6552,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [156799,
#   'MacMurray Ranch Central Coast Pinot Noir 2014',
#   '2014',
#   90,
#   5572,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [136121,
#   'Chapter 24 Fire and Flood The Flood Pinot Noir 2012',
#   '2012',
#   94,
#   999996819,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [111789,
#   'Chateau Leoville Poyferre  2009',
#   '2009',
#   100,
#   5913,
#   144,
#   124,
#   10050,
#   10038,
#   None],
#  [132113,
#   'Dugat-Py Mazis Chambertin 2003',
#   '2003',
#   96,
#   999997190,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [154579,
#   'Diamond Creek Volcanic Hill Cabernet Sauvignon 2013',
#   '2013',
#   100,
#   8527,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [156908,
#   'Woodward Canyon Artist Series Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   8533,
#   139,
#   124,
#   2414,
#   104,
#   None],
#  [155774,
#   'Ridge Geyserville 2014',
#   '2014',
#   93,
#   8345,
#   145,
#   124,
#   2371,
#   101,
#   None],
#  [151412,
#   'Decoy Sonoma Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   999998524,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [147826,
#   'Robert Mondavi Napa Valley Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   8844,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [158389,
#   'Duckhorn Three Palms Merlot 2013',
#   '2013',
#   98,
#   8808,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [152015,
#   'Wirra Wirra Church Block CSM 2013',
#   '2013',
#   94,
#   7972,
#   145,
#   124,
#   9063,
#   108,
#   None],
#  [131788,
#   'Chateau Lyonnat Lussac Saint Emilion 2009',
#   '2009',
#   90,
#   8148,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [156560,
#   "Stag's Leap Wine Cellars Fay Vineyard Cabernet Sauvignon 2013",
#   '2013',
#   95,
#   8754,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [161852,
#   "Stag's Leap Wine Cellars S.L.V. Cabernet Sauvignon (1.5 Liter Magnum) 2013",
#   '2013',
#   96,
#   8754,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [138756,
#   'Marcassin Marcassin Vineyard Pinot Noir 2010',
#   '2010',
#   98,
#   999999525,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [159824,
#   'Trefethen Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   8748,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [143048,
#   "Tenuta dell'Ornellaia (1.5 Liter Magnum) 2012",
#   '2012',
#   97,
#   7837,
#   144,
#   124,
#   2452,
#   105,
#   None],
#  [162292,
#   'DAOU Vineyards Cabernet Sauvignon 2015',
#   '2015',
#   94,
#   999997989,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [156279,
#   'Siduri John Sebastiano Vineyard Pinot Noir 2013',
#   '2013',
#   94,
#   10518,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [156787, 'Dominus Estate 2013', '2013', 100, 8073, 144, 124, 2398, 101, None],
#  [163463,
#   'Allegrini Palazzo della Torre 2013',
#   '2013',
#   0,
#   7989,
#   145,
#   124,
#   2352,
#   105,
#   None],
#  [123000,
#   'Chateau Mouton Rothschild  2010',
#   '2010',
#   100,
#   999999169,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [137182,
#   'Honig Cabernet Sauvignon 2013',
#   '2013',
#   91,
#   8340,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [163028,
#   'Far Niente Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   8634,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [158457,
#   'Hall Napa Valley Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   6019,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [158175,
#   'Sequoia Grove Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   8517,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [142182,
#   'Seghesio Home Ranch Zinfandel 2012',
#   '2012',
#   94,
#   8762,
#   141,
#   124,
#   2371,
#   101,
#   None],
#  [157727,
#   'Domaine Lafage Bastide Miraflors Vieilles Vignes 2014',
#   '2014',
#   92,
#   6568,
#   10082,
#   124,
#   2374,
#   102,
#   None],
#  [149127,
#   'Le Macchiole Paleo 2011',
#   '2011',
#   95,
#   7906,
#   197,
#   124,
#   2452,
#   105,
#   None],
#  [159686,
#   'Levet La Chavaroche Cote Rotie 2013',
#   '2013',
#   95,
#   999997041,
#   146,
#   124,
#   10053,
#   10039,
#   None],
#  [160208,
#   'Doubleback Cabernet Sauvignon 2013',
#   '2013',
#   95,
#   999998737,
#   139,
#   124,
#   1956,
#   104,
#   None],
#  [163307,
#   'Joseph Swan Pinot Noir Russian River Valley Cuvee de Trois 2013',
#   '2013',
#   0,
#   7062,
#   143,
#   124,
#   1863,
#   101,
#   None],
#  [159817, 'Justin Savant 2012', '2012', 94, 8701, 145, 124, 2462, 101, None],
#  [146436,
#   'Line 39 Pinot Noir 2014',
#   '2014',
#   90,
#   999996920,
#   143,
#   124,
#   2388,
#   101,
#   None],
#  [157545,
#   'Justin Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   8701,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [128858,
#   "d'Arenberg d'Arrys Original Shiraz/Grenache 2010",
#   '2010',
#   91,
#   8692,
#   10082,
#   124,
#   9063,
#   108,
#   None],
#  [153297,
#   'Chateau Malartic-Lagraviere (Futures Pre-Sale) 2015',
#   '2015',
#   97,
#   999999143,
#   144,
#   124,
#   10051,
#   10038,
#   None],
#  [154345,
#   'Elouan Pinot Noir 2014',
#   '2014',
#   0,
#   999996958,
#   143,
#   124,
#   2158,
#   103,
#   None],
#  [146466,
#   "Adelsheim Elizabeth's Reserve Pinot Noir 2012",
#   '2012',
#   95,
#   8716,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [157849,
#   'B Side Napa Valley Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   999999276,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [146914,
#   'Clarendon Hills Clarendon Vineyard Grenache 2010',
#   '2010',
#   94,
#   8382,
#   10080,
#   124,
#   9063,
#   108,
#   None],
#  [156607,
#   'Los Vascos Cabernet Sauvignon 2015',
#   '2015',
#   92,
#   8688,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [122860,
#   'Chateau Rauzan-Segla  2010',
#   '2010',
#   98,
#   999999038,
#   144,
#   124,
#   10040,
#   10038,
#   None],
#  [135074,
#   'Chateau Pontet-Canet (1.5 Liter Magnum) 2009',
#   '2009',
#   100,
#   5917,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [160638,
#   'Ghost Block Single Vineyard Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   999999529,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [163221,
#   'Ojai Bien Nacido Pinot Noir 2014',
#   '2014',
#   95,
#   8335,
#   143,
#   124,
#   2124,
#   101,
#   None],
#  [159319,
#   'Conundrum Red Blend 2014',
#   '2014',
#   0,
#   8726,
#   145,
#   124,
#   2388,
#   101,
#   None],
#  [124735,
#   'Pepperwood Grove Pinot Noir',
#   'Non-Vintage',
#   0,
#   7821,
#   143,
#   124,
#   2428,
#   112,
#   None],
#  [155370,
#   'Trentadue La Storia Zinfandel 2014',
#   '2014',
#   0,
#   7811,
#   141,
#   124,
#   2371,
#   101,
#   None],
#  [153131,
#   'Luigi Bosca Malbec 2013',
#   '2013',
#   92,
#   6084,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [147730,
#   'Sella & Mosca Terre Rare Riserva Carignano 2010',
#   '2010',
#   92,
#   6359,
#   195,
#   124,
#   10068,
#   105,
#   None],
#  [155192,
#   'Conti Costanti Brunello di Montalcino 2011',
#   '2011',
#   94,
#   10138,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [154452,
#   'Piedrasassi Santa Barbara County Syrah 2013',
#   '2013',
#   94,
#   6513,
#   146,
#   124,
#   2462,
#   101,
#   None],
#  [150270,
#   'Antinori Pian Delle Vigne Brunello Di Montalcino 2010',
#   '2010',
#   96,
#   8966,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [153738,
#   'Ritual Casablanca Valley Pinot Noir 2015',
#   '2015',
#   93,
#   999998234,
#   143,
#   124,
#   2428,
#   112,
#   None],
#  [160170,
#   'Il Palagio Message in a Bottle 2013',
#   '2013',
#   0,
#   999997481,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [160243,
#   'Marques de Murrieta Rioja Reserva 2011',
#   '2011',
#   91,
#   8951,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [91595,
#   'Antinori Tignanello 2004',
#   '2004',
#   95,
#   8966,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [151258,
#   'Giacomo Conterno Monfortino Barolo Riserva 2006',
#   '2006',
#   100,
#   999997986,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [96220,
#   'Chateau Pontet-Canet  2005',
#   '2005',
#   97,
#   5917,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [157831,
#   'Monte Antico Rosso 2012',
#   '2012',
#   91,
#   8804,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [111781,
#   'Chateau Duhart-Milon  2009',
#   '2009',
#   97,
#   999999127,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [141765,
#   'Scribe Napa Valley Syrah 2011',
#   '2011',
#   0,
#   999996314,
#   146,
#   124,
#   2398,
#   101,
#   None],
#  [155773,
#   'Banfi Brunello di Montalcino 2011',
#   '2011',
#   92,
#   8964,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [154318,
#   'Jean-Louis Chave Hermitage (1.5 Liter Magnum) 2010',
#   '2010',
#   100,
#   8534,
#   146,
#   124,
#   10055,
#   10039,
#   None],
#  [159093,
#   'Clos des Fous Cauquenina 2013',
#   '2013',
#   94,
#   999995089,
#   145,
#   124,
#   2428,
#   112,
#   None],
#  [157046,
#   'Tenuta San Guido Sassicaia 2013',
#   '2013',
#   98,
#   5432,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [135166, 'Gaja Barbaresco 2011', '2011', 95, 8061, 170, 124, 2431, 105, None],
#  [152482,
#   'Chateau Franc Mayne  2010',
#   '2010',
#   94,
#   999996498,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [140991,
#   'William Hill North Coast Cabernet Sauvignon 2013',
#   '2013',
#   0,
#   8560,
#   139,
#   124,
#   2416,
#   101,
#   None],
#  [157709,
#   'Chateau Gazin (Futures Pre-Sale) 2015',
#   '2015',
#   96,
#   999999132,
#   144,
#   124,
#   10043,
#   10038,
#   None],
#  [155597,
#   'Mayacamas Cabernet Sauvignon 2010',
#   '2010',
#   95,
#   8466,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [162709,
#   'Buena Vista The Sheriff Red Blend 2014',
#   '2014',
#   0,
#   8912,
#   145,
#   124,
#   2371,
#   101,
#   None],
#  [155555,
#   'Alexander Valley Vineyards Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   8869,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [156051,
#   'Tapiz Alta Collection Malbec 2013',
#   '2013',
#   95,
#   7364,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [153480,
#   'Resonance Pinot Noir Resonance Vineyard 2013',
#   '2013',
#   94,
#   999995466,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [162546,
#   'Statti Calabria Arvino 2013',
#   '2013',
#   0,
#   999999573,
#   145,
#   124,
#   2143,
#   105,
#   None],
#  [151616,
#   'Schug Carneros Pinot Noir 2014',
#   '2014',
#   93,
#   8008,
#   143,
#   124,
#   2454,
#   101,
#   None],
#  [97170,
#   'Chateau Malescot St. Exupery  2005',
#   '2005',
#   97,
#   7349,
#   144,
#   124,
#   10040,
#   10038,
#   None],
#  [162099,
#   'Domenico Clerico Barolo 2011',
#   '2011',
#   94,
#   999998938,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [156319,
#   'Locations by Dave Phinney CA-4',
#   'Non-Vintage',
#   90,
#   999997130,
#   145,
#   124,
#   2398,
#   101,
#   None],
#  [143191,
#   'Domaine des Lambrays Clos Des Lambrays 2011',
#   '2011',
#   93,
#   5973,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [147721,
#   'Atlas Peak Napa Valley Cabernet Sauvignon 2013',
#   '2013',
#   0,
#   8575,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [156390,
#   'Beaux Freres Willamette Valley Pinot Noir 2014',
#   '2014',
#   91,
#   8693,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [154362,
#   'Wild Ridge Pinot Noir 2013',
#   '2013',
#   91,
#   999997258,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [154621,
#   'Sur de los Andes Malbec Cabernet Sauvignon Premium Blend 2010',
#   '2010',
#   91,
#   999998208,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [151441,
#   'Patricia Green Freedom Hill Pinot Noir 2014',
#   '2014',
#   93,
#   8010,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [143352,
#   'Clarendelle Rouge 2010',
#   '2010',
#   90,
#   999998448,
#   144,
#   124,
#   10051,
#   10038,
#   None],
#  [154799,
#   'Oberon Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   6572,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [157300,
#   'Chateau de Vaudieu Val de Dieu Chateauneuf-du-Pape 2012',
#   '2012',
#   95,
#   999996373,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [155423,
#   'Bodega Noemia de Patagonia Rio Negro Valley Malbec 2013',
#   '2013',
#   98,
#   999999319,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [136316,
#   'Corliss Red 2009',
#   '2009',
#   94,
#   999998478,
#   144,
#   124,
#   2414,
#   104,
#   None],
#  [160479,
#   'PlumpJack Merlot 2014',
#   '2014',
#   93,
#   7528,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [52963,
#   'Chateau Lafite Rothschild  1999',
#   '1999',
#   95,
#   999999160,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [146612,
#   'DAOU Vineyards Cabernet Sauvignon 2014',
#   '2014',
#   91,
#   999997989,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [161063,
#   'Staglin Cabernet Sauvignon (1.5 Liter Magnum) 2012',
#   '2012',
#   96,
#   8185,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [160670,
#   "Guigal Chateau D'Ampuis Cote Rotie 2012",
#   '2012',
#   96,
#   8657,
#   146,
#   124,
#   10053,
#   10039,
#   None],
#  [153433,
#   'Chateau du Cartillon Haut Medoc 2014',
#   '2014',
#   91,
#   9284,
#   144,
#   124,
#   10041,
#   10038,
#   None],
#  [118819,
#   'Le Dome  2010',
#   '2010',
#   100,
#   999998091,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [123859,
#   'Cayuse Bionic Frog Syrah 2005',
#   '2005',
#   98,
#   5773,
#   146,
#   124,
#   1956,
#   104,
#   None],
#  [155962,
#   'Nicolas-Jay Pinot Noir 2014',
#   '2014',
#   95,
#   999995237,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [155354,
#   "Stags' Leap Winery Petite Sirah 2013",
#   '2013',
#   90,
#   8834,
#   176,
#   124,
#   2398,
#   101,
#   None],
#  [156837,
#   'Bodegas El Nido El Nido 2013',
#   '2013',
#   0,
#   6345,
#   145,
#   124,
#   9065,
#   109,
#   None],
#  [144482,
#   'Hahn Winery Monterey Pinot Noir 2014',
#   '2014',
#   0,
#   8341,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [157346,
#   'Beringer Knights Valley Reserve Cabernet Sauvignon 2012',
#   '2012',
#   93,
#   8866,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [152295,
#   'Argyle Reserve Pinot Noir 2013',
#   '2013',
#   0,
#   8182,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [154068,
#   'Guigal Gigondas Rouge 2012',
#   '2012',
#   92,
#   8657,
#   10082,
#   124,
#   10059,
#   10039,
#   None],
#  [156106,
#   'The Prisoner Wine Company Saldo Zinfandel 2014',
#   '2014',
#   0,
#   999997499,
#   141,
#   124,
#   2388,
#   101,
#   None],
#  [152560,
#   'Acrobat Pinot Noir 2014',
#   '2014',
#   0,
#   999998888,
#   143,
#   124,
#   2158,
#   103,
#   None],
#  [156548,
#   "Stag's Leap Wine Cellars Cask 23 Cabernet Sauvignon 2013",
#   '2013',
#   97,
#   8754,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [126664,
#   "Stag's Leap Wine Cellars Cask 23 Cabernet Sauvignon 2010",
#   '2010',
#   92,
#   8754,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [146917,
#   'Clarendon Hills Blewitt Springs Grenache 2010',
#   '2010',
#   96,
#   8382,
#   10080,
#   124,
#   9063,
#   108,
#   None],
#  [101442,
#   'Domaine du Vieux Telegraphe Chateauneuf-du-Pape La Crau 2007',
#   '2007',
#   96,
#   6695,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [103797,
#   "Chateau Cos d'Estournel  2008",
#   '2008',
#   95,
#   999999130,
#   144,
#   124,
#   10044,
#   10038,
#   None],
#  [115547,
#   'Capanna Brunello di Montalcino Riserva 2006',
#   '2006',
#   95,
#   999998662,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [162249,
#   'Hartford Russian River Zinfandel 2014',
#   '2014',
#   94,
#   999998958,
#   141,
#   124,
#   1863,
#   101,
#   None],
#  [153695,
#   'Josh Cellars Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   999998374,
#   139,
#   124,
#   2416,
#   101,
#   None],
#  [146578,
#   "Frog's Leap Estate Grown Cabernet Sauvignon 2013",
#   '2013',
#   93,
#   8794,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [152256,
#   'Dry Creek Vineyard Heritage Zinfandel 2014',
#   '2014',
#   93,
#   5562,
#   141,
#   124,
#   2371,
#   101,
#   None],
#  [158825,
#   'Calera Central Coast Pinot Noir 2014',
#   '2014',
#   92,
#   8816,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [152138,
#   'Penfolds Kalimna Bin 28 Shiraz 2013',
#   '2013',
#   94,
#   8903,
#   146,
#   124,
#   9058,
#   108,
#   None],
#  [157657,
#   'Fess Parker Santa Rita Hills Pinot Noir 2013',
#   '2013',
#   90,
#   8679,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [155294,
#   "Jacob's Creek Double Barrel Cabernet Sauvignon",
#   'Non-Vintage',
#   94,
#   6040,
#   139,
#   124,
#   9060,
#   108,
#   None],
#  [155312,
#   'Guigal Cotes du Rhone Rouge 2012',
#   '2012',
#   90,
#   8657,
#   10082,
#   124,
#   10061,
#   10039,
#   None],
#  [162980,
#   'Paul Hobbs Beckstoffer Las Piedras Cabernet Sauvignon 2013',
#   '2013',
#   98,
#   8348,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [156321,
#   'Locations by Dave Phinney E-4',
#   'Non-Vintage',
#   0,
#   999997130,
#   145,
#   124,
#   9065,
#   109,
#   None],
#  [147792,
#   'Mollydooker Blue Eyed Boy Shiraz 2014',
#   '2014',
#   93,
#   6105,
#   146,
#   124,
#   10078,
#   108,
#   None],
#  [147867,
#   'Michael David Winery Earthquake Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   999999918,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [142824,
#   'Chateau Lynch-Bages (Futures Pre-Sale) 2014',
#   '2014',
#   96,
#   999999161,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [143242,
#   'Vietti Barolo Lazzarito 2011',
#   '2011',
#   96,
#   7712,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [161734,
#   'Darioush Signature Cabernet Sauvignon 2013',
#   '2013',
#   0,
#   8100,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [145677,
#   'Concha y Toro Don Melchor Cabernet Sauvignon 2011',
#   '2011',
#   95,
#   8963,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [142645,
#   "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2012",
#   '2012',
#   93,
#   8111,
#   139,
#   124,
#   1956,
#   104,
#   None],
#  [151914,
#   'Mazzei Philip Cabernet Sauvignon 2011',
#   '2011',
#   93,
#   999997856,
#   139,
#   124,
#   2452,
#   105,
#   None],
#  [138326,
#   'Atalon Cabernet Sauvignon 2012',
#   '2012',
#   93,
#   8511,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [128677,
#   'Louis Bernard Cotes du Rhone Villages 2012',
#   '2012',
#   90,
#   8651,
#   10082,
#   124,
#   10061,
#   10039,
#   None],
#  [154904,
#   'Blackbird Vineyards Paramour Napa Valley Proprietary Red 2013',
#   '2013',
#   93,
#   999999430,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [134795,
#   'Cherry Pie Stanly Ranch Pinot Noir 2012',
#   '2012',
#   90,
#   999997991,
#   143,
#   124,
#   2454,
#   101,
#   None],
#  [151371,
#   'Formidable Napa Valley Merlot 2012',
#   '2012',
#   0,
#   999997905,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [145108,
#   'Hoopes Vineyard Oakville Cabernet Sauvignon 2012',
#   '2012',
#   95,
#   999997692,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [135468,
#   "Tenuta dell'Ornellaia Le Serre Nuove 2012",
#   '2012',
#   93,
#   7837,
#   144,
#   124,
#   2452,
#   105,
#   None],
#  [154422,
#   'Castello dei Rampolla Chianti Classico 2013',
#   '2013',
#   93,
#   5309,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [131513,
#   'Francis Ford Coppola Eleanor 2010',
#   '2010',
#   0,
#   999997855,
#   145,
#   124,
#   2416,
#   101,
#   None],
#  [155888,
#   'Willamette Valley Vineyards Whole Cluster Pinot Noir 2015',
#   '2015',
#   89,
#   8576,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [146885,
#   'Ravenswood Belloni Ranch Zinfandel 2012',
#   '2012',
#   95,
#   8769,
#   141,
#   124,
#   1863,
#   101,
#   None],
#  [161716,
#   'Caymus Special Selection Cabernet Sauvignon (1.5 Liter Magnum) 2013',
#   '2013',
#   95,
#   8626,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [119876,
#   'Chateau Margaux  2009',
#   '2009',
#   100,
#   999999164,
#   144,
#   124,
#   10040,
#   10038,
#   None],
#  [138875,
#   'The Prisoner Wine Company Thorn Merlot 2012',
#   '2012',
#   91,
#   999997499,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [156499,
#   'Tolaini Valdisanti Toscana 2011',
#   '2011',
#   92,
#   999999769,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [139801,
#   'Mercer Canyons Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   999996692,
#   139,
#   124,
#   2414,
#   104,
#   None],
# ...
#   93,
#   999996819,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [147292,
#   "La Fenetre A'Cote Pinot Noir 2013",
#   '2013',
#   90,
#   999996855,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [139282,
#   'Chateau Haut-Bailly  2012',
#   '2012',
#   96,
#   999998920,
#   144,
#   124,
#   10051,
#   10038,
#   None],
#  [147848,
#   'Clayhouse Adobe Red 2012',
#   '2012',
#   0,
#   999998265,
#   145,
#   124,
#   2462,
#   101,
#   None],
#  [153566,
#   'Francis Ford Coppola Diamond Collection Claret 2014',
#   '2014',
#   0,
#   999997855,
#   144,
#   124,
#   2388,
#   101,
#   None],
#  [162992, 'Torbreck RunRig 2013', '2013', 98, 5458, 146, 124, 9058, 108, None],
#  [159809,
#   'La Gerla Riserva Vigna Gli Angeli Brunello di Montalcino 2010',
#   '2010',
#   96,
#   8299,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [164124,
#   'Taltarni Pyrenees Shiraz 2014',
#   '2014',
#   0,
#   8464,
#   146,
#   124,
#   10077,
#   108,
#   None],
#  [158658,
#   'Trefethen Merlot 2013',
#   '2013',
#   92,
#   8748,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [153170,
#   'Siduri Sta. Rita Hills Pinot Noir 2013',
#   '2013',
#   93,
#   10518,
#   143,
#   124,
#   2462,
#   101,
#   None],
#  [153483,
#   'Emblem Napa Valley Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   999998609,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [140673,
#   'Buehler Bon Marche Red Blend 2012',
#   '2012',
#   0,
#   8911,
#   145,
#   124,
#   2388,
#   101,
#   None],
#  [131244,
#   "Tenuta dell'Ornellaia (1.5 Liter Magnum) 2011",
#   '2011',
#   97,
#   7837,
#   144,
#   124,
#   2452,
#   105,
#   None],
#  [155359,
#   'Gaja Rennina Brunello di Montalcino 2011',
#   '2011',
#   94,
#   8061,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [153606,
#   'Stoller Vineyards Dundee Hills Pinot Noir 2014',
#   '2014',
#   91,
#   999998917,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [161326,
#   'Mount Eden Vineyards Estate Pinot Noir 2013',
#   '2013',
#   94,
#   7870,
#   143,
#   124,
#   965,
#   101,
#   None],
#  [101756,
#   'Chateau Berliquet  2004',
#   '2004',
#   0,
#   999999056,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [162589,
#   'Serafin Pere & Fils Gevrey-Chambertin Premier Cru Le Fonteny 2009',
#   '2009',
#   93,
#   999997046,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [159032,
#   "Patz & Hall Gap's Crown Sonoma Coast Pinot Noir (1.5 Liter) 2013",
#   '2013',
#   93,
#   8370,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [153807,
#   'Mocali Brunello di Montalcino Riserva 2007',
#   '2007',
#   96,
#   5528,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [149987,
#   'Catena Zapata Argentino Vineyard Malbec 2011',
#   '2011',
#   95,
#   8363,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [150705,
#   'Tangley Oaks Merlot 2012',
#   '2012',
#   91,
#   999999733,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [162759,
#   'Roberts + Rogers Louer Family Cabernet Sauvignon 2013',
#   '2013',
#   95,
#   999994813,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [109022,
#   'Joseph Phelps Insignia 2008',
#   '2008',
#   97,
#   8881,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [152217,
#   "Frog's Leap Merlot (1.5 Liter Magnum) 2013",
#   '2013',
#   92,
#   8794,
#   138,
#   124,
#   2398,
#   101,
#   None],
#  [142140,
#   'Numanthia Termes 2012',
#   '2012',
#   91,
#   6390,
#   169,
#   124,
#   9065,
#   109,
#   None],
#  [158681,
#   'Patz & Hall Sonoma Coast Pinot Noir 2014',
#   '2014',
#   90,
#   8370,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [144505,
#   'Brassfield Eruption Red Blend 2013',
#   '2013',
#   92,
#   5747,
#   145,
#   124,
#   2416,
#   101,
#   None],
#  [153498,
#   'Silver Palm Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   999996757,
#   139,
#   124,
#   2416,
#   101,
#   None],
#  [162247,
#   'Buil and Gine Gine Gine Priorat 2014',
#   '2014',
#   91,
#   5365,
#   10082,
#   124,
#   9066,
#   109,
#   None],
#  [150051,
#   'Frescobaldi Nipozzano Chianti Rufina Riserva 2012',
#   '2012',
#   92,
#   8894,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [89254,
#   'Chateau Pichon-Longueville Baron  2003',
#   '2003',
#   95,
#   999999173,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [155729,
#   "Chateau de la Negly L'Ancely Coteaux du Languedoc 2011",
#   '2011',
#   96,
#   999995274,
#   10082,
#   124,
#   2374,
#   102,
#   None],
#  [163751, 'Tetra Red 2008', '2008', 94, 999996167, 144, 124, 2398, 101, None],
#  [155642,
#   'Domaine Grosbois Chinon Gabare 2014',
#   '2014',
#   90,
#   999997299,
#   197,
#   124,
#   2333,
#   102,
#   None],
#  [160482,
#   'Raymond Reserve Selection Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   8957,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [150531,
#   'Penfolds Bin 407 Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   8903,
#   139,
#   124,
#   2405,
#   108,
#   None],
#  [160119,
#   'Luce Della Vite Luce Brunello di Montalcino 2011',
#   '2011',
#   95,
#   7995,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [162318,
#   'Decoy Merlot 2014',
#   '2014',
#   90,
#   999998524,
#   138,
#   124,
#   2371,
#   101,
#   None],
#  [145668,
#   'Evodia Old Vine Grenache 2014',
#   '2014',
#   90,
#   999999432,
#   10080,
#   124,
#   9065,
#   109,
#   None],
#  [146934,
#   'Luce Della Vite Lucente 2013',
#   '2013',
#   92,
#   7995,
#   145,
#   124,
#   2452,
#   105,
#   None],
#  [155290,
#   'Bonterra Organically Grown Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   8638,
#   139,
#   124,
#   2416,
#   101,
#   None],
#  [151494,
#   'Frei Brothers Reserve Dry Creek Zinfandel 2014',
#   '2014',
#   92,
#   8602,
#   141,
#   124,
#   2371,
#   101,
#   None],
#  [128165,
#   'Montes Alpha Series Cabernet Sauvignon 2011',
#   '2011',
#   90,
#   8408,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [13938,
#   'Chateau Lafite Rothschild  1997',
#   '1997',
#   92,
#   999999160,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [160527,
#   'Felsina Chianti Classico Riserva Rancia (1.5 Liter Magnum) 2012',
#   '2012',
#   94,
#   5257,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [42786,
#   'Chateau Lynch-Bages  2000',
#   '2000',
#   97,
#   999999161,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [151452,
#   'Louis Jadot Chapelle-Chambertin 2013',
#   '2013',
#   97,
#   5687,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [152216,
#   "Frog's Leap Zinfandel (1.5 Liter Magnum) 2013",
#   '2013',
#   91,
#   8794,
#   141,
#   124,
#   2398,
#   101,
#   None],
#  [111784,
#   'Chateau Grand-Puy-Lacoste  2009',
#   '2009',
#   95,
#   999999156,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [163428,
#   'Yangarra Estate GSM 2014',
#   '2014',
#   96,
#   6257,
#   10082,
#   124,
#   9063,
#   108,
#   None],
#  [162560,
#   'Balletto Winery Russian River Valley Estate Pinot Noir 2014',
#   '2014',
#   0,
#   999997264,
#   143,
#   124,
#   1863,
#   101,
#   None],
#  [123680,
#   'Browne Family Vineyards Red Blend 2010',
#   '2010',
#   90,
#   999997728,
#   144,
#   124,
#   2414,
#   104,
#   None],
#  [149764,
#   'Luiano Chianti Classico (375ML half-bottle) 2013',
#   '2013',
#   0,
#   10500,
#   163,
#   124,
#   2143,
#   105,
#   None],
#  [156777,
#   'Albert Bichot Aloxe Corton Premier Cru Marechaudes 2013',
#   '2013',
#   92,
#   8436,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [146507,
#   'Yealands Peter Yealands Pinot Noir 2014',
#   '2014',
#   91,
#   999999295,
#   143,
#   124,
#   10071,
#   114,
#   None],
#  [137943,
#   'Allegrini Palazzo della Torre 2012',
#   '2012',
#   92,
#   7989,
#   145,
#   124,
#   2352,
#   105,
#   None],
#  [146961,
#   'Tour Saint-Michel Chateauneuf-du-Pape Cuvee du Lion 2012',
#   '2012',
#   93,
#   999997077,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [141625,
#   'Borsao Tres Picos Garnacha 2013',
#   '2013',
#   91,
#   7957,
#   10080,
#   124,
#   9065,
#   109,
#   None],
#  [155272,
#   "Stags' Leap Winery The Investor Red Wine 2013",
#   '2013',
#   93,
#   8834,
#   145,
#   124,
#   2398,
#   101,
#   None],
#  [144503,
#   'Robert Mondavi Oakville District Cabernet Sauvignon 2012',
#   '2012',
#   91,
#   8844,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [146656,
#   'Domaine de Courcel Pommard Premier Cru Grand Clos des Epenots 2011',
#   '2011',
#   93,
#   999995883,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [148501,
#   'Franciscan Estate Cabernet Sauvignon 2013',
#   '2013',
#   90,
#   8800,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [159659,
#   'Shatter Grenache 2013',
#   '2013',
#   0,
#   999998062,
#   10080,
#   124,
#   2374,
#   102,
#   None],
#  [156175,
#   'Aquinas Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   6291,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [148175,
#   'Domaine Faiveley Mazis-Chambertin Grand Cru 2013',
#   '2013',
#   95,
#   999999847,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [131222,
#   'Mad Housewife Cellars Cabernet Sauvignon',
#   'Non-Vintage',
#   0,
#   999997188,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [155217,
#   'Carnivor Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   999996872,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [154806,
#   "Francis Ford Coppola Director's Cut Alexander Valley Cabernet Sauvignon 2014",
#   '2014',
#   0,
#   999997855,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [154829,
#   'G.D. Vajra Bricco Delle Viole Barolo 2011',
#   '2011',
#   95,
#   8407,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [152516,
#   'Domaine du Vieux Telegraphe Chateauneuf-du-Pape Telegramme 2013',
#   '2013',
#   90,
#   6695,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [158347,
#   'Luigi Pira Barolo Serralunga 2012',
#   '2012',
#   0,
#   999999606,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [131829,
#   'Felsina Fontalloro (375ML half-bottle) 2010',
#   '2010',
#   95,
#   5257,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [156438,
#   'Martinelli Vellutini Ranch Syrah 2012',
#   '2012',
#   95,
#   7075,
#   146,
#   124,
#   1863,
#   101,
#   None],
#  [132704,
#   'Folie a Deux Dry Creek Zinfandel 2012',
#   '2012',
#   93,
#   8326,
#   141,
#   124,
#   2371,
#   101,
#   None],
#  [152257,
#   'Turnbull Cabernet Sauvignon 2013',
#   '2013',
#   93,
#   8725,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [146442,
#   'The Counselor Alexander Valley Cabernet Sauvignon 2013',
#   '2013',
#   92,
#   999996052,
#   139,
#   124,
#   2371,
#   101,
#   None],
#  [142781,
#   'Chateau Faugeres (Futures Pre-Sale) 2014',
#   '2014',
#   95,
#   999999123,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [156583,
#   'Twenty Rows Napa Cabernet Sauvignon 2014',
#   '2014',
#   0,
#   999997060,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [133296,
#   'Domaine Cecile Tremblay Morey-Saint-Denis Tres Girard 2010',
#   '2010',
#   91,
#   999997045,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [146922,
#   'Clarendon Hills Bakers Gully Syrah 2010',
#   '2010',
#   94,
#   8382,
#   146,
#   124,
#   9063,
#   108,
#   None],
#  [153078,
#   'J. Lohr Hilltop Cabernet Sauvignon 2013',
#   '2013',
#   0,
#   8744,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [136166,
#   'Concha y Toro Don Melchor Cabernet Sauvignon 2010',
#   '2010',
#   96,
#   8963,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [103592,
#   'Chateau Montrose  2008',
#   '2008',
#   95,
#   999999167,
#   144,
#   124,
#   10044,
#   10038,
#   None],
#  [143068,
#   'Wente The Nth Degree Cabernet Sauvignon 2012',
#   '2012',
#   0,
#   8908,
#   139,
#   124,
#   2462,
#   101,
#   None],
#  [150670,
#   'Louis Latour Beaune Premier Cru Vignes Franches 2013',
#   '2013',
#   93,
#   6537,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [147682,
#   'Paraduxx Proprietary Red 2012',
#   '2012',
#   90,
#   6340,
#   145,
#   124,
#   2398,
#   101,
#   None],
#  [129796, 'Dominus Estate 2011', '2011', 94, 8073, 144, 124, 2398, 101, None],
#  [163585,
#   'La Spinetta Barolo Garretti 2012',
#   '2012',
#   94,
#   6358,
#   170,
#   124,
#   2431,
#   105,
#   None],
#  [152817,
#   'Matetic EQ Pinot Noir 2013',
#   '2013',
#   93,
#   9520,
#   143,
#   124,
#   2428,
#   112,
#   None],
#  [146326,
#   'Mas Doix Salanques 2012',
#   '2012',
#   93,
#   6095,
#   145,
#   124,
#   9066,
#   109,
#   None],
#  [138647,
#   'Montes Cabernet Sauvignon 2013',
#   '2013',
#   0,
#   8408,
#   139,
#   124,
#   2428,
#   112,
#   None],
#  [149310,
#   'Kings Ridge Pinot Noir 2014',
#   '2014',
#   89,
#   999999777,
#   143,
#   124,
#   2474,
#   103,
#   None],
#  [159053,
#   'Pascual Toso Malbec Reserve 2014',
#   '2014',
#   0,
#   5375,
#   10079,
#   124,
#   2089,
#   112,
#   None],
#  [160777,
#   'La Massa Chianti Classico 2013',
#   '2013',
#   93,
#   9883,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [160444, 'Kunde Merlot 2014', '2014', 0, 8793, 138, 124, 2371, 101, None],
#  [152587,
#   'Simple Life Pinot Noir 2014',
#   '2014',
#   0,
#   999996438,
#   143,
#   124,
#   2388,
#   101,
#   None],
#  [162774,
#   'Chateau Margaux  2012',
#   '2012',
#   96,
#   999999164,
#   144,
#   124,
#   10040,
#   10038,
#   None],
#  [145537,
#   'Lynsolence  2012',
#   '2012',
#   94,
#   999995978,
#   138,
#   124,
#   10042,
#   10038,
#   None],
#  [118126,
#   'Maybach Family Vineyards Materium 2008',
#   '2008',
#   96,
#   999999036,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [155223,
#   'William Harrison Simpatico 2012',
#   '2012',
#   0,
#   999996472,
#   145,
#   124,
#   2398,
#   101,
#   None],
#  [139533,
#   'Cote Bonneville Carriage House Red Blend 2009',
#   '2009',
#   94,
#   999996804,
#   144,
#   124,
#   2052,
#   104,
#   None],
#  [141361,
#   'Domaine de Marcoux Cotes-du-Rhone 2011',
#   '2011',
#   90,
#   9758,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [153989,
#   'Chateau Les Graves de Barrau  2014',
#   '2014',
#   0,
#   999999024,
#   144,
#   124,
#   2263,
#   10038,
#   None],
#  [142789,
#   'Dona Paula Black Edition Red Blend 2013',
#   '2013',
#   90,
#   999999549,
#   144,
#   124,
#   2089,
#   112,
#   None],
#  [147184,
#   'Domaine Charbonniere Chateauneuf-du-Pape 2013',
#   '2013',
#   92,
#   999998602,
#   10082,
#   124,
#   10057,
#   10039,
#   None],
#  [134616,
#   'Domaine Faiveley Mercurey Rouge 2012',
#   '2012',
#   0,
#   999999847,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [123200,
#   'Leonetti Reserve 2010',
#   '2010',
#   100,
#   999999855,
#   144,
#   124,
#   1956,
#   104,
#   None],
#  [151318,
#   'Marcassin Three Sisters Vineyard Pinot Noir 2010',
#   '2010',
#   96,
#   999999525,
#   143,
#   124,
#   2371,
#   101,
#   None],
#  [154072,
#   'Jaboulet Hermitage La Chapelle 2012',
#   '2012',
#   97,
#   8916,
#   146,
#   124,
#   10055,
#   10039,
#   None],
#  [117657,
#   'Cayuse Armada Syrah 2007',
#   '2007',
#   98,
#   5773,
#   146,
#   124,
#   1956,
#   104,
#   None],
#  [152528,
#   'Avalon California Cabernet Sauvignon 2013',
#   '2013',
#   0,
#   -2147483648,
#   139,
#   124,
#   2388,
#   101,
#   None],
#  [138478,
#   'Domaine Jean Grivot Vosne Romanee 1er Cru Les Beaux Monts 2011',
#   '2011',
#   95,
#   5967,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [107369,
#   'Fontodi Flaccianello 2007',
#   '2007',
#   95,
#   9241,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [140504,
#   'Cayuse Cailloux Syrah 2012',
#   '2012',
#   96,
#   5773,
#   146,
#   124,
#   1956,
#   104,
#   None],
#  [106468,
#   'David Arthur Elevation 1147 Estate Cabernet Sauvignon (slightly torn labels) 2007',
#   '2007',
#   96,
#   9865,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [141469,
#   "Stag's Leap Wine Cellars Cask 23 Cabernet Sauvignon 2012",
#   '2012',
#   96,
#   8754,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [154354,
#   'Bodegas Muriel Reserva 2011',
#   '2011',
#   90,
#   999998558,
#   169,
#   124,
#   2370,
#   109,
#   None],
#  [161777,
#   'Mount Veeder Winery Cabernet Sauvignon (375ML Half-Bottle) 2013',
#   '2013',
#   92,
#   999999037,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [158129,
#   'Bodegas y Vinedos Alion  2012',
#   '2012',
#   95,
#   8222,
#   169,
#   124,
#   9067,
#   109,
#   None],
#  [142940,
#   'Seven Hills Winery Columbia Valley Cabernet Sauvignon 2013',
#   '2013',
#   0,
#   7461,
#   139,
#   124,
#   2414,
#   104,
#   None],
#  [160218,
#   'Fattoria dei Barbi Brunello di Montalcino 2011',
#   '2011',
#   92,
#   7746,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [161667,
#   'Lamole di Lamole Chianti Classico Riserva 2012',
#   '2012',
#   93,
#   8371,
#   163,
#   124,
#   2452,
#   105,
#   None],
#  [147315,
#   'Far Niente Cabernet Sauvignon 2013',
#   '2013',
#   94,
#   8634,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [161174,
#   'Rochioli West Block Pinot Noir 2012',
#   '2012',
#   96,
#   5605,
#   143,
#   124,
#   1863,
#   101,
#   None],
#  [103666,
#   'Chateau Canon La Gaffeliere  2008',
#   '2008',
#   94,
#   999999151,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [160959,
#   'Chateau Lynch-Bages  2012',
#   '2012',
#   95,
#   999999161,
#   144,
#   124,
#   10049,
#   10038,
#   None],
#  [147586,
#   'Jean-Claude Boisset Chateau de Prieureux Bourgogne Rouge 2013',
#   '2013',
#   0,
#   999999177,
#   143,
#   124,
#   2457,
#   102,
#   None],
#  [153764,
#   'Domaine Andron  2010',
#   '2010',
#   91,
#   999995458,
#   144,
#   124,
#   10041,
#   10038,
#   None],
#  [156373,
#   'Shannon Ridge Wrangler Red 2013',
#   '2013',
#   90,
#   6192,
#   145,
#   124,
#   2416,
#   101,
#   None],
#  [146509,
#   'Robert Mondavi Reserve Cabernet Sauvignon 2012',
#   '2012',
#   95,
#   8844,
#   139,
#   124,
#   2398,
#   101,
#   None],
#  [161312,
#   'Miner Family The Oracle 2012',
#   '2012',
#   0,
#   8399,
#   144,
#   124,
#   2398,
#   101,
#   None],
#  [157627,
#   'Gramercy Cellars Columbia Valley Lagniappe Syrah 2013',
#   '2013',
#   95,
#   999999497,
#   146,
#   124,
#   2414,
#   104,
#   None],
#  [118831,
#   'Les Asteries  2010',
#   '2010',
#   96,
#   999999418,
#   144,
#   124,
#   10042,
#   10038,
#   None],
#  [161359,
#   'Tooth & Nail The Possessor Tolliver Ranch Vineyard 2014',
#   '2014',
#   0,
#   999996816,
#   145,
#   124,
#   2388,
#   101,
#   None]]

# %%
len(main_wines)
# Out:
# 1000

# %%
varietals
# Out:
# [[144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [195,
#   'Other Red Wine',
#   'http://www.wine.com/v6/Other-Red-Wine/wine/list.aspx?N=7155+124+195'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [197,
#   'Cabernet Franc',
#   'http://www.wine.com/v6/Cabernet-Franc/wine/list.aspx?N=7155+124+197'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [197,
#   'Cabernet Franc',
#   'http://www.wine.com/v6/Cabernet-Franc/wine/list.aspx?N=7155+124+197'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [197,
#   'Cabernet Franc',
#   'http://www.wine.com/v6/Cabernet-Franc/wine/list.aspx?N=7155+124+197'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [195,
#   'Other Red Wine',
#   'http://www.wine.com/v6/Other-Red-Wine/wine/list.aspx?N=7155+124+195'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [176,
#   'Petite Sirah',
#   'http://www.wine.com/v6/Petite-Sirah/wine/list.aspx?N=7155+124+176'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
# ...
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [197,
#   'Cabernet Franc',
#   'http://www.wine.com/v6/Cabernet-Franc/wine/list.aspx?N=7155+124+197'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [195,
#   'Other Red Wine',
#   'http://www.wine.com/v6/Other-Red-Wine/wine/list.aspx?N=7155+124+195'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [197,
#   'Cabernet Franc',
#   'http://www.wine.com/v6/Cabernet-Franc/wine/list.aspx?N=7155+124+197'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [10080,
#   'Grenache',
#   'http://www.wine.com/v6/Grenache/wine/list.aspx?N=7155+124+10080'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [141,
#   'Zinfandel',
#   'http://www.wine.com/v6/Zinfandel/wine/list.aspx?N=7155+124+141'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [170,
#   'Nebbiolo',
#   'http://www.wine.com/v6/Nebbiolo/wine/list.aspx?N=7155+124+170'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [10079,
#   'Malbec',
#   'http://www.wine.com/v6/Malbec/wine/list.aspx?N=7155+124+10079'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [138,
#   'Merlot',
#   'http://www.wine.com/v6/Merlot/wine/list.aspx?N=7155+124+138'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [10082,
#   'Rhone Red Blends',
#   'http://www.wine.com/v6/Rhone-Red-Blends/wine/list.aspx?N=7155+124+10082'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [169,
#   'Tempranillo',
#   'http://www.wine.com/v6/Tempranillo/wine/list.aspx?N=7155+124+169'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [163,
#   'Sangiovese',
#   'http://www.wine.com/v6/Sangiovese/wine/list.aspx?N=7155+124+163'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [143,
#   'Pinot Noir',
#   'http://www.wine.com/v6/Pinot-Noir/wine/list.aspx?N=7155+124+143'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145'],
#  [139,
#   'Cabernet Sauvignon',
#   'http://www.wine.com/v6/Cabernet-Sauvignon/wine/list.aspx?N=7155+124+139'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [146,
#   'Syrah/Shiraz',
#   'http://www.wine.com/v6/SyrahShiraz/wine/list.aspx?N=7155+124+146'],
#  [144,
#   'Bordeaux Red Blends',
#   'http://www.wine.com/v6/Bordeaux-Red-Blends/wine/list.aspx?N=7155+124+144'],
#  [145,
#   'Other Red Blends',
#   'http://www.wine.com/v6/Other-Red-Blends/wine/list.aspx?N=7155+124+145']]

# %%
wine_types
# Out:
# [[124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
# ...
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124'],
#  [124,
#   'Red Wines',
#   'http://www.wine.com/v6/Red-Wines/wine/list.aspx?N=7155+124']]

# %%
appellations
# Out:
# [[2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2428, 'Chile'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [10049, 'Pauillac'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [10049, 'Pauillac'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [10049, 'Pauillac'],
#  [2370, 'Rioja'],
#  [10049, 'Pauillac'],
#  [2474, 'Willamette Valley'],
#  [10043, 'Pomerol'],
#  [2452, 'Tuscany'],
#  [2052, 'Yakima Valley'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2398, 'Napa Valley'],
#  [9063, 'McLaren Vale'],
#  [2398, 'Napa Valley'],
#  [10044, 'St. Estephe'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [10066, 'Sicily'],
#  [10043, 'Pomerol'],
#  [2452, 'Tuscany'],
#  [10043, 'Pomerol'],
#  [2371, 'Sonoma County'],
#  [10049, 'Pauillac'],
#  [10044, 'St. Estephe'],
#  [10049, 'Pauillac'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [10043, 'Pomerol'],
#  [10049, 'Pauillac'],
#  [10049, 'Pauillac'],
#  [10042, 'St-Emilion'],
#  [2370, 'Rioja'],
#  [10071, 'Marlborough'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [10047, 'Fronsac'],
#  [2452, 'Tuscany'],
#  [2416, 'North Coast'],
#  [2398, 'Napa Valley'],
#  [10043, 'Pomerol'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2416, 'North Coast'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2371, 'Sonoma County'],
#  [2474, 'Willamette Valley'],
#  [2288, 'Sierra Foothills'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2428, 'Chile'],
#  [2370, 'Rioja'],
#  [2428, 'Chile'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [9063, 'McLaren Vale'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2370, 'Rioja'],
#  [2398, 'Napa Valley'],
#  [2462, 'Central Coast'],
#  [2370, 'Rioja'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [2462, 'Central Coast'],
#  [2452, 'Tuscany'],
#  [2371, 'Sonoma County'],
#  [9065, 'Other Spain'],
#  [2452, 'Tuscany'],
#  [2371, 'Sonoma County'],
#  [2370, 'Rioja'],
#  [2089, 'Argentina'],
#  [2462, 'Central Coast'],
#  [2414, 'Columbia Valley'],
#  [2452, 'Tuscany'],
#  [1956, 'Walla Walla Valley'],
#  [2370, 'Rioja'],
#  [2309, 'Other Italian'],
#  [2452, 'Tuscany'],
#  [10047, 'Fronsac'],
#  [2398, 'Napa Valley'],
#  [10042, 'St-Emilion'],
#  [2388, 'Other California'],
#  [2452, 'Tuscany'],
#  [10055, 'Hermitage'],
#  [2414, 'Columbia Valley'],
#  [2388, 'Other California'],
#  [2398, 'Napa Valley'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2263, 'Other Bordeaux'],
#  [2375, 'Other Rhône'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2414, 'Columbia Valley'],
#  [2371, 'Sonoma County'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [9067, 'Ribera del Duero'],
#  [2398, 'Napa Valley'],
#  [10040, 'Margaux'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2089, 'Argentina'],
#  [2398, 'Napa Valley'],
#  [2462, 'Central Coast'],
#  [10041, 'Medoc'],
#  [2398, 'Napa Valley'],
#  [2370, 'Rioja'],
#  [10049, 'Pauillac'],
#  [2414, 'Columbia Valley'],
#  [10049, 'Pauillac'],
#  [2431, 'Piedmont'],
#  [2371, 'Sonoma County'],
#  [2428, 'Chile'],
#  [2428, 'Chile'],
#  [2452, 'Tuscany'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [9063, 'McLaren Vale'],
#  [2428, 'Chile'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [10049, 'Pauillac'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2428, 'Chile'],
#  [2398, 'Napa Valley'],
#  [2370, 'Rioja'],
#  [2374, 'Languedoc-Roussillon'],
#  [10055, 'Hermitage'],
#  [2371, 'Sonoma County'],
#  [10049, 'Pauillac'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2452, 'Tuscany'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2398, 'Napa Valley'],
#  [2263, 'Other Bordeaux'],
#  [2462, 'Central Coast'],
#  [2431, 'Piedmont'],
#  [2431, 'Piedmont'],
#  [9058, 'Barossa Valley'],
#  [2089, 'Argentina'],
#  [2452, 'Tuscany'],
#  [2462, 'Central Coast'],
#  [10053, 'Cote Rotie'],
#  [10068, 'Sardinia'],
#  [2052, 'Yakima Valley'],
#  [2462, 'Central Coast'],
#  [2452, 'Tuscany'],
#  [1863, 'Russian River'],
#  [2462, 'Central Coast'],
#  [9062, 'Margaret River'],
#  [2462, 'Central Coast'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [10051, 'Pessac-Leognan'],
#  [2371, 'Sonoma County'],
#  [2398, 'Napa Valley'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [10043, 'Pomerol'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [9067, 'Ribera del Duero'],
#  [2352, 'Veneto'],
#  [2462, 'Central Coast'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [2370, 'Rioja'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [2416, 'North Coast'],
#  [2452, 'Tuscany'],
#  [10051, 'Pessac-Leognan'],
#  [2124, 'Santa Maria Valley'],
#  [2398, 'Napa Valley'],
#  [2431, 'Piedmont'],
#  [1956, 'Walla Walla Valley'],
#  [9062, 'Margaret River'],
#  [2309, 'Other Italian'],
#  [2370, 'Rioja'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2398, 'Napa Valley'],
#  [2416, 'North Coast'],
#  [2089, 'Argentina'],
#  [10042, 'St-Emilion'],
#  [1956, 'Walla Walla Valley'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [9063, 'McLaren Vale'],
#  [10041, 'Medoc'],
#  [2452, 'Tuscany'],
#  [2089, 'Argentina'],
#  [2371, 'Sonoma County'],
#  [2398, 'Napa Valley'],
#  [2416, 'North Coast'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2428, 'Chile'],
#  [2462, 'Central Coast'],
#  [2388, 'Other California'],
#  [2474, 'Willamette Valley'],
#  [10049, 'Pauillac'],
#  [1863, 'Russian River'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2474, 'Willamette Valley'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2431, 'Piedmont'],
#  [2388, 'Other California'],
#  [9065, 'Other Spain'],
#  [2388, 'Other California'],
#  [2388, 'Other California'],
#  [10042, 'St-Emilion'],
#  [2462, 'Central Coast'],
#  [2474, 'Willamette Valley'],
#  [10050, 'St-Julien'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [2414, 'Columbia Valley'],
#  [2371, 'Sonoma County'],
#  [2371, 'Sonoma County'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [9063, 'McLaren Vale'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [2462, 'Central Coast'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2352, 'Veneto'],
#  [10049, 'Pauillac'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2374, 'Languedoc-Roussillon'],
#  [2452, 'Tuscany'],
#  [10053, 'Cote Rotie'],
#  [1956, 'Walla Walla Valley'],
#  [1863, 'Russian River'],
#  [2462, 'Central Coast'],
#  [2388, 'Other California'],
#  [2462, 'Central Coast'],
#  [9063, 'McLaren Vale'],
#  [10051, 'Pessac-Leognan'],
#  [2158, 'Other Oregon'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [9063, 'McLaren Vale'],
#  [2428, 'Chile'],
#  [10040, 'Margaux'],
#  [10049, 'Pauillac'],
#  [2398, 'Napa Valley'],
#  [2124, 'Santa Maria Valley'],
#  [2388, 'Other California'],
#  [2428, 'Chile'],
#  [2371, 'Sonoma County'],
#  [2089, 'Argentina'],
#  [10068, 'Sardinia'],
#  [2452, 'Tuscany'],
#  [2462, 'Central Coast'],
#  [2452, 'Tuscany'],
#  [2428, 'Chile'],
#  [2452, 'Tuscany'],
#  [2370, 'Rioja'],
#  [2452, 'Tuscany'],
#  [2431, 'Piedmont'],
#  [10049, 'Pauillac'],
#  [2452, 'Tuscany'],
#  [10049, 'Pauillac'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [10055, 'Hermitage'],
#  [2428, 'Chile'],
#  [2452, 'Tuscany'],
#  [2431, 'Piedmont'],
#  [10042, 'St-Emilion'],
#  [2416, 'North Coast'],
#  [10043, 'Pomerol'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2371, 'Sonoma County'],
#  [2089, 'Argentina'],
#  [2474, 'Willamette Valley'],
#  [2143, 'Southern Italy'],
#  [2454, 'Carneros'],
#  [10040, 'Margaux'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [2474, 'Willamette Valley'],
#  [2371, 'Sonoma County'],
#  [2089, 'Argentina'],
#  [2474, 'Willamette Valley'],
#  [10051, 'Pessac-Leognan'],
#  [2398, 'Napa Valley'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2089, 'Argentina'],
#  [2414, 'Columbia Valley'],
#  [2398, 'Napa Valley'],
#  [10049, 'Pauillac'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [10053, 'Cote Rotie'],
#  [10041, 'Medoc'],
#  [10042, 'St-Emilion'],
#  [1956, 'Walla Walla Valley'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [9065, 'Other Spain'],
#  [2462, 'Central Coast'],
#  [2371, 'Sonoma County'],
#  [2474, 'Willamette Valley'],
#  [10059, 'Gigondas'],
#  [2388, 'Other California'],
#  [2158, 'Other Oregon'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [9063, 'McLaren Vale'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [10044, 'St. Estephe'],
#  [2452, 'Tuscany'],
#  [1863, 'Russian River'],
#  [2416, 'North Coast'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2462, 'Central Coast'],
#  [9058, 'Barossa Valley'],
#  [2462, 'Central Coast'],
#  [9060, 'Coonawarra'],
#  [10061, 'Cotes du Rhone'],
#  [2398, 'Napa Valley'],
#  [9065, 'Other Spain'],
#  [10078, 'South Australia'],
#  [2388, 'Other California'],
#  [10049, 'Pauillac'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [2428, 'Chile'],
#  [1956, 'Walla Walla Valley'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [10061, 'Cotes du Rhone'],
#  [2398, 'Napa Valley'],
#  [2454, 'Carneros'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2416, 'North Coast'],
#  [2474, 'Willamette Valley'],
#  [1863, 'Russian River'],
#  [2398, 'Napa Valley'],
#  [10040, 'Margaux'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [2414, 'Columbia Valley'],
#  [2416, 'North Coast'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2431, 'Piedmont'],
#  [1863, 'Russian River'],
#  [2370, 'Rioja'],
#  [965, 'Santa Cruz Mountains'],
#  [2371, 'Sonoma County'],
#  [2474, 'Willamette Valley'],
#  [2370, 'Rioja'],
#  [2462, 'Central Coast'],
#  [2462, 'Central Coast'],
#  [2431, 'Piedmont'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [10075, 'Navarra'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2263, 'Other Bordeaux'],
#  [2089, 'Argentina'],
#  [2371, 'Sonoma County'],
#  [2462, 'Central Coast'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [2283, 'South Africa'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [10051, 'Pessac-Leognan'],
#  [2452, 'Tuscany'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2089, 'Argentina'],
#  [2457, 'Burgundy'],
#  [1863, 'Russian River'],
#  [2428, 'Chile'],
#  [2370, 'Rioja'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [9063, 'McLaren Vale'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [1863, 'Russian River'],
#  [2474, 'Willamette Valley'],
#  [2405, 'Other Australia'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2452, 'Tuscany'],
#  [2388, 'Other California'],
#  [2405, 'Other Australia'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2052, 'Yakima Valley'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [2416, 'North Coast'],
#  [2457, 'Burgundy'],
#  [1863, 'Russian River'],
#  [2398, 'Napa Valley'],
#  [2370, 'Rioja'],
#  [2398, 'Napa Valley'],
#  [2431, 'Piedmont'],
#  [2352, 'Veneto'],
#  [2398, 'Napa Valley'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [10071, 'Marlborough'],
#  [2089, 'Argentina'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [10050, 'St-Julien'],
#  [2089, 'Argentina'],
#  [2474, 'Willamette Valley'],
#  [2431, 'Piedmont'],
#  [2371, 'Sonoma County'],
#  [2371, 'Sonoma County'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [2352, 'Veneto'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [10059, 'Gigondas'],
#  [2398, 'Napa Valley'],
#  [2352, 'Veneto'],
#  [2089, 'Argentina'],
#  [2388, 'Other California'],
#  [2388, 'Other California'],
#  [2428, 'Chile'],
#  [2398, 'Napa Valley'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2414, 'Columbia Valley'],
#  [2089, 'Argentina'],
#  [2388, 'Other California'],
#  [2388, 'Other California'],
#  [2431, 'Piedmont'],
#  [1863, 'Russian River'],
#  [2398, 'Napa Valley'],
#  [10041, 'Medoc'],
#  [10049, 'Pauillac'],
#  [10044, 'St. Estephe'],
#  [1863, 'Russian River'],
#  [10061, 'Cotes du Rhone'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2405, 'Other Australia'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [2371, 'Sonoma County'],
#  [2370, 'Rioja'],
#  [2452, 'Tuscany'],
#  [10061, 'Cotes du Rhone'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [1956, 'Walla Walla Valley'],
#  [1863, 'Russian River'],
#  [2283, 'South Africa'],
#  [2398, 'Napa Valley'],
#  [-2147483648, 'Other Washington'],
#  [2089, 'Argentina'],
#  [10040, 'Margaux'],
#  [1863, 'Russian River'],
#  [2398, 'Napa Valley'],
#  [2089, 'Argentina'],
#  [1863, 'Russian River'],
#  [2462, 'Central Coast'],
#  [2462, 'Central Coast'],
#  [2374, 'Languedoc-Roussillon'],
#  [2388, 'Other California'],
#  [9058, 'Barossa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2474, 'Willamette Valley'],
#  [2452, 'Tuscany'],
#  [2428, 'Chile'],
#  [2414, 'Columbia Valley'],
#  [2452, 'Tuscany'],
#  [10051, 'Pessac-Leognan'],
#  [9067, 'Ribera del Duero'],
#  [1956, 'Walla Walla Valley'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2370, 'Rioja'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2428, 'Chile'],
#  [2428, 'Chile'],
#  [2431, 'Piedmont'],
#  [10041, 'Medoc'],
#  [2462, 'Central Coast'],
#  [2462, 'Central Coast'],
#  [2414, 'Columbia Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2414, 'Columbia Valley'],
#  [10040, 'Margaux'],
#  [2474, 'Willamette Valley'],
#  [2462, 'Central Coast'],
#  [2377, 'Portugal'],
#  [2371, 'Sonoma County'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [2089, 'Argentina'],
#  [2462, 'Central Coast'],
#  [9058, 'Barossa Valley'],
#  [2089, 'Argentina'],
#  [2288, 'Sierra Foothills'],
#  [2398, 'Napa Valley'],
#  [1863, 'Russian River'],
#  [2474, 'Willamette Valley'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2089, 'Argentina'],
#  [2388, 'Other California'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [10042, 'St-Emilion'],
#  [2462, 'Central Coast'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2309, 'Other Italian'],
#  [-2147483648, ''],
#  [2371, 'Sonoma County'],
#  [2474, 'Willamette Valley'],
#  [2457, 'Burgundy'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [1863, 'Russian River'],
#  [2398, 'Napa Valley'],
#  [1863, 'Russian River'],
#  [2375, 'Other Rhône'],
#  [10051, 'Pessac-Leognan'],
#  [2462, 'Central Coast'],
#  [2388, 'Other California'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2352, 'Veneto'],
#  [2457, 'Burgundy'],
#  [2452, 'Tuscany'],
#  [2416, 'North Coast'],
#  [9059, 'Clare Valley'],
#  [2089, 'Argentina'],
#  [2462, 'Central Coast'],
#  [2462, 'Central Coast'],
#  [9063, 'McLaren Vale'],
#  [2457, 'Burgundy'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2352, 'Veneto'],
#  [2474, 'Willamette Valley'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [2428, 'Chile'],
#  [2370, 'Rioja'],
#  [2374, 'Languedoc-Roussillon'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [2052, 'Yakima Valley'],
#  [2428, 'Chile'],
#  [2371, 'Sonoma County'],
#  [2388, 'Other California'],
#  [2454, 'Carneros'],
#  [1956, 'Walla Walla Valley'],
#  [1956, 'Walla Walla Valley'],
#  [9058, 'Barossa Valley'],
#  [2158, 'Other Oregon'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [2414, 'Columbia Valley'],
#  [2388, 'Other California'],
#  [2428, 'Chile'],
#  [2388, 'Other California'],
#  [2388, 'Other California'],
#  [2452, 'Tuscany'],
#  [10073, 'Central Otago'],
#  [2398, 'Napa Valley'],
#  [1863, 'Russian River'],
#  [2454, 'Carneros'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2283, 'South Africa'],
#  [2414, 'Columbia Valley'],
#  [10043, 'Pomerol'],
#  [2398, 'Napa Valley'],
#  [2416, 'North Coast'],
#  [10051, 'Pessac-Leognan'],
#  [10043, 'Pomerol'],
#  [2388, 'Other California'],
#  [10043, 'Pomerol'],
#  [2370, 'Rioja'],
#  [2371, 'Sonoma County'],
#  [10066, 'Sicily'],
#  [2431, 'Piedmont'],
#  [2398, 'Napa Valley'],
#  [9062, 'Margaret River'],
#  [2416, 'North Coast'],
#  [2454, 'Carneros'],
#  [10043, 'Pomerol'],
#  [2398, 'Napa Valley'],
#  [2414, 'Columbia Valley'],
#  [2089, 'Argentina'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2405, 'Other Australia'],
#  [10044, 'St. Estephe'],
#  [2398, 'Napa Valley'],
#  [2428, 'Chile'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [10059, 'Gigondas'],
#  [10051, 'Pessac-Leognan'],
#  [10050, 'St-Julien'],
#  [2283, 'South Africa'],
#  [2452, 'Tuscany'],
#  [2405, 'Other Australia'],
#  [2388, 'Other California'],
#  [2388, 'Other California'],
#  [2288, 'Sierra Foothills'],
#  [2398, 'Napa Valley'],
#  [2452, 'Tuscany'],
#  [10042, 'St-Emilion'],
#  [2052, 'Yakima Valley'],
#  [10042, 'St-Emilion'],
#  [2431, 'Piedmont'],
#  [2428, 'Chile'],
#  [2398, 'Napa Valley'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [1956, 'Walla Walla Valley'],
#  [1956, 'Walla Walla Valley'],
#  [2377, 'Portugal'],
#  [10043, 'Pomerol'],
#  [10041, 'Medoc'],
#  [2388, 'Other California'],
#  [1863, 'Russian River'],
#  [2431, 'Piedmont'],
#  [2283, 'South Africa'],
#  [2414, 'Columbia Valley'],
#  [2462, 'Central Coast'],
#  [2431, 'Piedmont'],
#  [2405, 'Other Australia'],
#  [9067, 'Ribera del Duero'],
#  [10040, 'Margaux'],
#  [2452, 'Tuscany'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [10066, 'Sicily'],
#  [10051, 'Pessac-Leognan'],
#  [2452, 'Tuscany'],
#  [2474, 'Willamette Valley'],
#  [2263, 'Other Bordeaux'],
#  [2374, 'Languedoc-Roussillon'],
#  [10043, 'Pomerol'],
#  [10066, 'Sicily'],
#  [1863, 'Russian River'],
#  [10061, 'Cotes du Rhone'],
#  [2089, 'Argentina'],
#  [2414, 'Columbia Valley'],
#  [2397, 'Beaujolais'],
#  [2371, 'Sonoma County'],
#  [9063, 'McLaren Vale'],
#  [2452, 'Tuscany'],
#  [9065, 'Other Spain'],
#  [2452, 'Tuscany'],
#  [9063, 'McLaren Vale'],
#  [9065, 'Other Spain'],
#  [2462, 'Central Coast'],
#  [2143, 'Southern Italy'],
#  [2462, 'Central Coast'],
#  [2454, 'Carneros'],
#  [10050, 'St-Julien'],
#  [1863, 'Russian River'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [-2147483648, 'Other Washington'],
#  [2452, 'Tuscany'],
#  [2428, 'Chile'],
#  [10042, 'St-Emilion'],
#  [2457, 'Burgundy'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [10066, 'Sicily'],
#  [2414, 'Columbia Valley'],
#  [2089, 'Argentina'],
#  [1956, 'Walla Walla Valley'],
#  [2431, 'Piedmont'],
#  [2462, 'Central Coast'],
#  [9065, 'Other Spain'],
#  [2452, 'Tuscany'],
#  [2431, 'Piedmont'],
#  [2457, 'Burgundy'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2398, 'Napa Valley'],
#  [2374, 'Languedoc-Roussillon'],
#  [2143, 'Southern Italy'],
#  [9065, 'Other Spain'],
#  [2405, 'Other Australia'],
#  [2462, 'Central Coast'],
#  [2089, 'Argentina'],
#  [2452, 'Tuscany'],
#  [10062, 'Vacqueyras'],
#  [2452, 'Tuscany'],
#  [2462, 'Central Coast'],
#  [2462, 'Central Coast'],
#  [-2147483648, 'Other Washington'],
#  [2414, 'Columbia Valley'],
#  [10071, 'Marlborough'],
#  [2371, 'Sonoma County'],
#  [2388, 'Other California'],
#  [9065, 'Other Spain'],
#  [2474, 'Willamette Valley'],
#  [2388, 'Other California'],
#  [2388, 'Other California'],
#  [2370, 'Rioja'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2431, 'Piedmont'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [10049, 'Pauillac'],
#  [2452, 'Tuscany'],
#  [1956, 'Walla Walla Valley'],
#  [2388, 'Other California'],
#  [10049, 'Pauillac'],
#  [1956, 'Walla Walla Valley'],
#  [1956, 'Walla Walla Valley'],
#  [2370, 'Rioja'],
#  [10049, 'Pauillac'],
#  [10070, 'Martinborough'],
#  [10049, 'Pauillac'],
#  [2431, 'Piedmont'],
#  [1455, 'Greece'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2398, 'Napa Valley'],
#  [2454, 'Carneros'],
#  [2371, 'Sonoma County'],
#  [2416, 'North Coast'],
#  [2452, 'Tuscany'],
#  [1956, 'Walla Walla Valley'],
#  [2462, 'Central Coast'],
#  [10053, 'Cote Rotie'],
#  [2371, 'Sonoma County'],
#  [10061, 'Cotes du Rhone'],
#  [2398, 'Napa Valley'],
#  [2474, 'Willamette Valley'],
#  [2457, 'Burgundy'],
#  [2371, 'Sonoma County'],
#  [2414, 'Columbia Valley'],
#  [1863, 'Russian River'],
#  [2089, 'Argentina'],
#  [2398, 'Napa Valley'],
#  [-2147483648, ''],
#  [2462, 'Central Coast'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [10078, 'South Australia'],
#  [9063, 'McLaren Vale'],
#  [2452, 'Tuscany'],
#  [2462, 'Central Coast'],
#  [9066, 'Priorat'],
#  [2428, 'Chile'],
#  [2452, 'Tuscany'],
#  [2428, 'Chile'],
#  [-2147483648, 'Other Washington'],
#  [2398, 'Napa Valley'],
#  [1863, 'Russian River'],
#  [2474, 'Willamette Valley'],
#  [2462, 'Central Coast'],
#  [10051, 'Pessac-Leognan'],
#  [2462, 'Central Coast'],
#  [2388, 'Other California'],
#  [9058, 'Barossa Valley'],
#  [2452, 'Tuscany'],
#  [10077, 'Victoria'],
#  [2398, 'Napa Valley'],
#  [2462, 'Central Coast'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2474, 'Willamette Valley'],
#  [965, 'Santa Cruz Mountains'],
#  [10042, 'St-Emilion'],
#  [2457, 'Burgundy'],
#  [2371, 'Sonoma County'],
#  [2452, 'Tuscany'],
#  [2089, 'Argentina'],
#  [2398, 'Napa Valley'],
#  [2388, 'Other California'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [9065, 'Other Spain'],
#  [2371, 'Sonoma County'],
#  [2416, 'North Coast'],
#  [2416, 'North Coast'],
#  [9066, 'Priorat'],
#  [2452, 'Tuscany'],
#  [10049, 'Pauillac'],
#  [2374, 'Languedoc-Roussillon'],
#  [2398, 'Napa Valley'],
#  [2333, 'Loire'],
#  [2398, 'Napa Valley'],
#  [2405, 'Other Australia'],
#  [2452, 'Tuscany'],
#  [2371, 'Sonoma County'],
#  [9065, 'Other Spain'],
#  [2452, 'Tuscany'],
#  [2416, 'North Coast'],
#  [2371, 'Sonoma County'],
#  [2428, 'Chile'],
#  [10049, 'Pauillac'],
#  [2452, 'Tuscany'],
#  [10049, 'Pauillac'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [10049, 'Pauillac'],
#  [9063, 'McLaren Vale'],
#  [1863, 'Russian River'],
#  [2414, 'Columbia Valley'],
#  [2143, 'Southern Italy'],
#  [2457, 'Burgundy'],
#  [10071, 'Marlborough'],
#  [2352, 'Veneto'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [9065, 'Other Spain'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [2374, 'Languedoc-Roussillon'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [2388, 'Other California'],
#  [2388, 'Other California'],
#  [2371, 'Sonoma County'],
#  [2431, 'Piedmont'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2431, 'Piedmont'],
#  [2452, 'Tuscany'],
#  [1863, 'Russian River'],
#  [2371, 'Sonoma County'],
#  [2398, 'Napa Valley'],
#  [2371, 'Sonoma County'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [2457, 'Burgundy'],
#  [9063, 'McLaren Vale'],
#  [2462, 'Central Coast'],
#  [2428, 'Chile'],
#  [10044, 'St. Estephe'],
#  [2462, 'Central Coast'],
#  [2457, 'Burgundy'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2431, 'Piedmont'],
#  [2428, 'Chile'],
#  [9066, 'Priorat'],
#  [2428, 'Chile'],
#  [2474, 'Willamette Valley'],
#  [2089, 'Argentina'],
#  [2452, 'Tuscany'],
#  [2371, 'Sonoma County'],
#  [2388, 'Other California'],
#  [10040, 'Margaux'],
#  [10042, 'St-Emilion'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2052, 'Yakima Valley'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2263, 'Other Bordeaux'],
#  [2089, 'Argentina'],
#  [10057, 'Chateauneuf-du-Pape'],
#  [2457, 'Burgundy'],
#  [1956, 'Walla Walla Valley'],
#  [2371, 'Sonoma County'],
#  [10055, 'Hermitage'],
#  [1956, 'Walla Walla Valley'],
#  [2388, 'Other California'],
#  [2457, 'Burgundy'],
#  [2452, 'Tuscany'],
#  [1956, 'Walla Walla Valley'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2370, 'Rioja'],
#  [2398, 'Napa Valley'],
#  [9067, 'Ribera del Duero'],
#  [2414, 'Columbia Valley'],
#  [2452, 'Tuscany'],
#  [2452, 'Tuscany'],
#  [2398, 'Napa Valley'],
#  [1863, 'Russian River'],
#  [10042, 'St-Emilion'],
#  [10049, 'Pauillac'],
#  [2457, 'Burgundy'],
#  [10041, 'Medoc'],
#  [2416, 'North Coast'],
#  [2398, 'Napa Valley'],
#  [2398, 'Napa Valley'],
#  [2414, 'Columbia Valley'],
#  [10042, 'St-Emilion'],
#  [2388, 'Other California']]

# %%
regions
# Out:
# [[101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [109, 'Spain'],
#  [10038, 'France - Bordeaux'],
#  [103, 'Oregon'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [109, 'Spain'],
#  [114, 'New Zealand'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [109, 'Spain'],
#  [112, 'South America'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [108, 'Australia'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [112, 'South America'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [10038, 'France - Bordeaux'],
#  [104, 'Washington'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [112, 'South America'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [108, 'Australia'],
#  [112, 'South America'],
#  [10039, 'France - Rhone'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [102, 'France - Other regions'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10039, 'France - Rhone'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [108, 'Australia'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [108, 'Australia'],
#  [105, 'Italy'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [10038, 'France - Bordeaux'],
#  [104, 'Washington'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [10038, 'France - Bordeaux'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [10038, 'France - Bordeaux'],
#  [103, 'Oregon'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [112, 'South America'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [103, 'Oregon'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [112, 'South America'],
#  [103, 'Oregon'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [112, 'South America'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [104, 'Washington'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [10039, 'France - Rhone'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [112, 'South America'],
#  [104, 'Washington'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [113, 'South Africa'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [112, 'South America'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [108, 'Australia'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [114, 'New Zealand'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [112, 'South America'],
#  [103, 'Oregon'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [10039, 'France - Rhone'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [113, 'South Africa'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [112, 'South America'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [104, 'Washington'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [109, 'Spain'],
#  [104, 'Washington'],
#  [10039, 'France - Rhone'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [10038, 'France - Bordeaux'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [107, 'Portugal'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [-2147483648, ''],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [102, 'France - Other regions'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [102, 'France - Other regions'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [109, 'Spain'],
#  [102, 'France - Other regions'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [104, 'Washington'],
#  [108, 'Australia'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [114, 'New Zealand'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [113, 'South Africa'],
#  [104, 'Washington'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [113, 'South Africa'],
#  [105, 'Italy'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [104, 'Washington'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [104, 'Washington'],
#  [107, 'Portugal'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [113, 'South Africa'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [108, 'Australia'],
#  [109, 'Spain'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [103, 'Oregon'],
#  [10038, 'France - Bordeaux'],
#  [102, 'France - Other regions'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [112, 'South America'],
#  [104, 'Washington'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [105, 'Italy'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [108, 'Australia'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [10038, 'France - Bordeaux'],
#  [102, 'France - Other regions'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [112, 'South America'],
#  [104, 'Washington'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [102, 'France - Other regions'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [105, 'Italy'],
#  [109, 'Spain'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [104, 'Washington'],
#  [114, 'New Zealand'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [104, 'Washington'],
#  [104, 'Washington'],
#  [109, 'Spain'],
#  [10038, 'France - Bordeaux'],
#  [114, 'New Zealand'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [115, 'Greece'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [112, 'South America'],
#  [101, 'California'],
#  [-2147483648, ''],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [108, 'Australia'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [105, 'Italy'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [103, 'Oregon'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [108, 'Australia'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [112, 'South America'],
#  [10038, 'France - Bordeaux'],
#  [105, 'Italy'],
#  [10038, 'France - Bordeaux'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [105, 'Italy'],
#  [102, 'France - Other regions'],
#  [114, 'New Zealand'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [10039, 'France - Rhone'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [108, 'Australia'],
#  [101, 'California'],
#  [112, 'South America'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [101, 'California'],
#  [101, 'California'],
#  [105, 'Italy'],
#  [112, 'South America'],
#  [109, 'Spain'],
#  [112, 'South America'],
#  [103, 'Oregon'],
#  [112, 'South America'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [10039, 'France - Rhone'],
#  [10038, 'France - Bordeaux'],
#  [112, 'South America'],
#  [10039, 'France - Rhone'],
#  [102, 'France - Other regions'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [10039, 'France - Rhone'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [102, 'France - Other regions'],
#  [105, 'Italy'],
#  [104, 'Washington'],
#  [101, 'California'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [101, 'California'],
#  [109, 'Spain'],
#  [104, 'Washington'],
#  [105, 'Italy'],
#  [105, 'Italy'],
#  [101, 'California'],
#  [101, 'California'],
#  [10038, 'France - Bordeaux'],
#  [10038, 'France - Bordeaux'],
#  [102, 'France - Other regions'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California'],
#  [101, 'California'],
#  [101, 'California'],
#  [104, 'Washington'],
#  [10038, 'France - Bordeaux'],
#  [101, 'California']]

# %%
areas
# Out:
# []

# %%
vineyards
# Out:
# [[7270, 'Pahlmeyer'],
#  [7396, 'Silver Oak Napa Valley'],
#  [6024, 'Haras de Pirque'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999997220, 'The Debate'],
#  [8509, 'Verite Estate'],
#  [8626, 'Caymus'],
#  [999997365, 'Moss Roxx'],
#  [8626, 'Caymus'],
#  [8808, 'Duckhorn Vineyards'],
#  [999999028, 'Château Latour'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [5616, 'Tenuta Sette Ponti'],
#  [7746, 'Fattoria dei Barbi'],
#  [8798, 'Freemark Abbey'],
#  [999999692, 'Carruades de Lafite'],
#  [8220, 'La Rioja Alta'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [8693, 'Beaux Freres'],
#  [999999170, 'Chateau Petrus'],
#  [7270, 'Pahlmeyer'],
#  [7396, 'Silver Oak Napa Valley'],
#  [6024, 'Haras de Pirque'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999997220, 'The Debate'],
#  [8509, 'Verite Estate'],
#  [8626, 'Caymus'],
#  [999997365, 'Moss Roxx'],
#  [8626, 'Caymus'],
#  [8808, 'Duckhorn Vineyards'],
#  [999999028, 'Château Latour'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [5616, 'Tenuta Sette Ponti'],
#  [7746, 'Fattoria dei Barbi'],
#  [8798, 'Freemark Abbey'],
#  [999999692, 'Carruades de Lafite'],
#  [8220, 'La Rioja Alta'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [8693, 'Beaux Freres'],
#  [999999170, 'Chateau Petrus'],
#  [7270, 'Pahlmeyer'],
#  [7396, 'Silver Oak Napa Valley'],
#  [6024, 'Haras de Pirque'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999997220, 'The Debate'],
#  [8509, 'Verite Estate'],
#  [8626, 'Caymus'],
#  [999997365, 'Moss Roxx'],
#  [8626, 'Caymus'],
#  [8808, 'Duckhorn Vineyards'],
#  [999999028, 'Château Latour'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [5616, 'Tenuta Sette Ponti'],
#  [7746, 'Fattoria dei Barbi'],
#  [8798, 'Freemark Abbey'],
#  [999999692, 'Carruades de Lafite'],
#  [8220, 'La Rioja Alta'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [8693, 'Beaux Freres'],
#  [999999170, 'Chateau Petrus'],
#  [7270, 'Pahlmeyer'],
#  [7396, 'Silver Oak Napa Valley'],
#  [6024, 'Haras de Pirque'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999997220, 'The Debate'],
#  [8509, 'Verite Estate'],
#  [8626, 'Caymus'],
#  [999997365, 'Moss Roxx'],
#  [8626, 'Caymus'],
#  [8808, 'Duckhorn Vineyards'],
#  [999999028, 'Château Latour'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [5616, 'Tenuta Sette Ponti'],
#  [7746, 'Fattoria dei Barbi'],
#  [8798, 'Freemark Abbey'],
#  [999999692, 'Carruades de Lafite'],
#  [8220, 'La Rioja Alta'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [8693, 'Beaux Freres'],
#  [999999170, 'Chateau Petrus'],
#  [7270, 'Pahlmeyer'],
#  [7396, 'Silver Oak Napa Valley'],
#  [6024, 'Haras de Pirque'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999997220, 'The Debate'],
#  [8509, 'Verite Estate'],
#  [8626, 'Caymus'],
#  [999997365, 'Moss Roxx'],
#  [8626, 'Caymus'],
#  [8808, 'Duckhorn Vineyards'],
#  [999999028, 'Château Latour'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [5616, 'Tenuta Sette Ponti'],
#  [7746, 'Fattoria dei Barbi'],
#  [8798, 'Freemark Abbey'],
#  [999999692, 'Carruades de Lafite'],
#  [8220, 'La Rioja Alta'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [8693, 'Beaux Freres'],
#  [999999170, 'Chateau Petrus'],
#  [8966, 'Antinori'],
#  [999996940, 'Canvasback'],
#  [8623, 'Nickel & Nickel'],
#  [8509, 'Verite Estate'],
#  [999999160, 'Chateau Lafite Rothschild'],
#  [999997962, 'Oakville Winery'],
#  [8382, 'Clarendon Hills'],
#  [999996814, 'Jamieson Ranch Vineyards'],
#  [999999167, 'Chateau Montrose'],
#  [8341, 'Hahn Winery'],
#  [8626, 'Caymus'],
#  [8485, 'Jordan Vineyard & Winery'],
#  [999998509, 'Benanti'],
#  [999999170, 'Chateau Petrus'],
#  [999998003, 'Bibi Graetz'],
#  [999999170, 'Chateau Petrus'],
#  [8509, 'Verite Estate'],
#  [5917, 'Chateau Pontet-Canet'],
#  [999999130, "Chateau Cos d'Estournel"],
#  [999999160, 'Chateau Lafite Rothschild'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [999997859, 'Mt. Brave'],
#  [8469, 'Clos du Val'],
#  [8844, 'Robert Mondavi Winery'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999999159, 'Chateau Lafleur'],
#  [999995860, 'Chateau Peymouton'],
#  [8101, 'CVNE'],
#  [999998220, 'Greywacke'],
#  [999997499, 'The Prisoner Wine Company'],
#  [8008, 'Schug Estate Winery'],
#  [8210, 'Castello di Monsanto'],
#  [8061, 'Gaja'],
#  [999999171, 'Chateau Pavie'],
#  [8469, 'Clos du Val'],
#  [8794, "Frog's Leap"],
#  [6048, 'Joel Gott'],
#  [999996970, 'Chateau Mayne Vieil'],
#  [8231, 'Borgo Scopeto'],
#  [999997909, 'Lucky'],
#  [999998771, 'Antica'],
#  [6554, 'Vieux Chateau Certan'],
#  [8061, 'Gaja'],
#  [5616, 'Tenuta Sette Ponti'],
#  [8894, 'Frescobaldi'],
#  [999999161, 'Chateau Lynch-Bages'],
#  [6449, 'Robert Stemmler'],
#  [6396, 'Clos des Papes'],
#  [999996787, 'Trombetta'],
#  [999996819, 'Chapter 24'],
#  [8794, "Frog's Leap"],
#  [5997, 'Faust'],
#  [8337, 'Rombauer Vineyards'],
#  [6024, 'Haras de Pirque'],
#  [999996026, 'Baron de Ley'],
#  [8963, 'Concha y Toro'],
#  [8788, 'Kendall-Jackson'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [8382, 'Clarendon Hills'],
#  [7372, 'Il Poggione'],
#  [8754, "Stag's Leap Wine Cellars"],
#  [8233, 'Domaine Drouhin Oregon'],
#  [999998393, 'CADE Winery'],
#  [999999478, 'Roots Run Deep'],
#  [8660, 'Bodegas Muga'],
#  [8677, 'Chappellet Winery'],
#  [5370, 'Miura Vineyards'],
#  [8660, 'Bodegas Muga'],
#  [999998393, 'CADE Winery'],
#  [7069, 'Meo-Camuzet'],
#  [8834, "Stags' Leap Winery"],
#  [8754, "Stag's Leap Wine Cellars"],
#  [999998126, 'Black Stallion Winery'],
#  [999999768, 'Donatella Cinelli Colombini'],
#  [6307, 'Treana Winery'],
#  [5257, 'Fattoria di Felsina'],
#  [5388, 'Flowers'],
#  [5257, 'Fattoria di Felsina'],
#  [8762, 'Seghesio Family Vineyards'],
#  [5714, 'Benjamin Romeo'],
#  [7270, 'Pahlmeyer'],
#  [7396, 'Silver Oak Napa Valley'],
#  [6024, 'Haras de Pirque'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999997220, 'The Debate'],
#  [8509, 'Verite Estate'],
#  [8626, 'Caymus'],
#  [999997365, 'Moss Roxx'],
#  [8626, 'Caymus'],
#  [8808, 'Duckhorn Vineyards'],
#  [999999028, 'Château Latour'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [5616, 'Tenuta Sette Ponti'],
#  [7746, 'Fattoria dei Barbi'],
#  [8798, 'Freemark Abbey'],
#  [999999692, 'Carruades de Lafite'],
#  [8220, 'La Rioja Alta'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [8693, 'Beaux Freres'],
#  [999999170, 'Chateau Petrus'],
#  [8966, 'Antinori'],
#  [999996940, 'Canvasback'],
#  [8623, 'Nickel & Nickel'],
#  [8509, 'Verite Estate'],
#  [999999160, 'Chateau Lafite Rothschild'],
#  [999997962, 'Oakville Winery'],
#  [8382, 'Clarendon Hills'],
#  [999996814, 'Jamieson Ranch Vineyards'],
#  [999999167, 'Chateau Montrose'],
#  [8341, 'Hahn Winery'],
#  [8626, 'Caymus'],
#  [8485, 'Jordan Vineyard & Winery'],
#  [999998509, 'Benanti'],
#  [999999170, 'Chateau Petrus'],
#  [999998003, 'Bibi Graetz'],
#  [999999170, 'Chateau Petrus'],
#  [8509, 'Verite Estate'],
#  [5917, 'Chateau Pontet-Canet'],
#  [999999130, "Chateau Cos d'Estournel"],
#  [999999160, 'Chateau Lafite Rothschild'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [999997859, 'Mt. Brave'],
#  [8469, 'Clos du Val'],
#  [8844, 'Robert Mondavi Winery'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999999159, 'Chateau Lafleur'],
#  [999995860, 'Chateau Peymouton'],
#  [8101, 'CVNE'],
#  [999998220, 'Greywacke'],
#  [999997499, 'The Prisoner Wine Company'],
#  [8008, 'Schug Estate Winery'],
#  [8210, 'Castello di Monsanto'],
#  [8061, 'Gaja'],
#  [999999171, 'Chateau Pavie'],
#  [8469, 'Clos du Val'],
#  [8794, "Frog's Leap"],
#  [6048, 'Joel Gott'],
#  [999996970, 'Chateau Mayne Vieil'],
#  [8231, 'Borgo Scopeto'],
#  [999997909, 'Lucky'],
#  [999998771, 'Antica'],
#  [6554, 'Vieux Chateau Certan'],
#  [8061, 'Gaja'],
#  [5616, 'Tenuta Sette Ponti'],
#  [8894, 'Frescobaldi'],
#  [999999161, 'Chateau Lynch-Bages'],
#  [6449, 'Robert Stemmler'],
#  [6396, 'Clos des Papes'],
#  [999996787, 'Trombetta'],
#  [999996819, 'Chapter 24'],
#  [8794, "Frog's Leap"],
#  [5997, 'Faust'],
#  [8337, 'Rombauer Vineyards'],
#  [6024, 'Haras de Pirque'],
#  [999996026, 'Baron de Ley'],
#  [8963, 'Concha y Toro'],
#  [8788, 'Kendall-Jackson'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [8382, 'Clarendon Hills'],
#  [7372, 'Il Poggione'],
#  [8754, "Stag's Leap Wine Cellars"],
#  [8233, 'Domaine Drouhin Oregon'],
#  [999998393, 'CADE Winery'],
#  [999999478, 'Roots Run Deep'],
#  [8660, 'Bodegas Muga'],
#  [8677, 'Chappellet Winery'],
#  [5370, 'Miura Vineyards'],
#  [8660, 'Bodegas Muga'],
#  [999998393, 'CADE Winery'],
#  [7069, 'Meo-Camuzet'],
#  [8834, "Stags' Leap Winery"],
#  [8754, "Stag's Leap Wine Cellars"],
#  [999998126, 'Black Stallion Winery'],
#  [999999768, 'Donatella Cinelli Colombini'],
#  [6307, 'Treana Winery'],
#  [5257, 'Fattoria di Felsina'],
#  [5388, 'Flowers'],
#  [5257, 'Fattoria di Felsina'],
#  [8762, 'Seghesio Family Vineyards'],
#  [5714, 'Benjamin Romeo'],
#  [999997354, 'Rafael Reverte'],
#  [999999704, 'Mendel'],
#  [6623, 'Smith & Hook Winery'],
#  [8491, 'Col Solare'],
#  [999994608, 'Masseto'],
#  [999999718, 'K Vintners'],
#  [8777, 'Faustino'],
#  [999996198, 'Le Potazzine'],
#  [999994832, 'Renzo Marinai'],
#  [999996970, 'Chateau Mayne Vieil'],
#  [999996472, 'William Harrison'],
#  [999999153, 'Chateau Cheval Blanc'],
#  [999999169, 'Chateau Mouton Rothschild'],
#  [8299, 'La Gerla'],
#  [999999528, 'Klinker Brick'],
#  [8857, 'M. Chapoutier'],
#  [8853, 'Columbia Crest'],
#  [999997417, 'Meiomi'],
#  [999998277, 'Robert Hall'],
#  [8634, 'Far Niente'],
#  [999996953, 'Orin Swift Cellars'],
#  [10026, 'Domaine Saint Prefert'],
#  [999999529, 'Ghost Block'],
#  [6169, 'Inglenook'],
#  [999994845, 'Intrinsic'],
#  [8345, 'Ridge'],
#  [7763, 'Chateau Les-Charmes Godard'],
#  [8716, 'Adelsheim'],
#  [7071, 'Barnett Vineyards'],
#  [8662, 'Abadia Retuerta'],
#  [8518, 'Cakebread'],
#  [999999164, 'Chateau Margaux'],
#  [8626, 'Caymus'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999998208, 'Sur de los Andes'],
#  [8887, 'Groth Vineyards & Winery'],
#  [8705, 'Bernardus'],
#  [8035, 'Chateau La Cardonne'],
#  [8575, 'Atlas Peak Winery'],
#  [8101, 'CVNE'],
#  [999999169, 'Chateau Mouton Rothschild'],
#  [999999678, 'Substance'],
#  [999999173, 'Chateau Pichon-Longueville Baron'],
#  [8407, 'G.D. Vajra'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [8070, 'Almaviva'],
#  [7960, 'Domus Aurea'],
#  [999994818, 'Farnetella'],
#  [999998601, 'Domaine de Cristia'],
#  [8382, 'Clarendon Hills'],
#  [8759, 'Lapostolle'],
#  [9711, 'Frank Family Vineyards'],
#  [999995114, 'Xavier Vins'],
#  [999999131, 'Chateau Clerc Milon'],
#  [5916, 'Chateau Montelena'],
#  [6191, 'Shafer Vineyards'],
#  [999998234, 'Ritual'],
#  [999999037, 'Mount Veeder Winery'],
#  [8101, 'CVNE'],
#  [999996113, 'Department 66'],
#  [8534, 'Jean-Louis Chave '],
#  [8762, 'Seghesio Family Vineyards'],
#  [999999173, 'Chateau Pichon-Longueville Baron'],
#  [8657, 'Guigal'],
#  [8225, 'Caparzo'],
#  [7847, 'Produttori del Barbaresco'],
#  [6019, 'Hall'],
#  [999997585, 'Reata'],
#  [8800, 'Franciscan Estate'],
#  [999996570, 'Noiro'],
#  [7847, 'Produttori del Barbaresco'],
#  [999998938, 'Domenico Clerico'],
#  [8728, 'Yalumba'],
#  [6351, 'Tikal'],
#  [6562, 'Giacomo Mori'],
#  [999999578, 'MooBuzz'],
#  [8657, 'Guigal'],
#  [999995136, 'Chateau le Doyenne'],
#  [6359, 'Sella & Mosca'],
#  [8503, 'J. Bookwalter'],
#  [8176, 'Belle Glos'],
#  [6998, 'Valdicava'],
#  [999999649, 'The Donum Estate'],
#  [999998723, 'Lucienne'],
#  [6403, 'Ringbolt'],
#  [999997989, 'DAOU Vineyards'],
#  [10660, 'Domaine Ponsot'],
#  [999996953, 'Orin Swift Cellars'],
#  [5916, 'Chateau Montelena'],
#  [999997499, 'The Prisoner Wine Company'],
#  [5616, 'Tenuta Sette Ponti'],
#  [999999165, 'Chateau Pape Clement'],
#  [8866, 'Beringer Vineyards'],
#  [8407, 'G.D. Vajra'],
#  [8527, 'Diamond Creek'],
#  [999999045, "Chateau L'Evangile"],
#  [8623, 'Nickel & Nickel'],
#  [999998524, 'Decoy'],
#  [999999035, 'Scarecrow'],
#  [8934, 'Condado de Haza'],
#  [7270, 'Pahlmeyer'],
#  [7396, 'Silver Oak Napa Valley'],
#  [6024, 'Haras de Pirque'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999997220, 'The Debate'],
#  [8509, 'Verite Estate'],
#  [999999160, 'Chateau Lafite Rothschild'],
#  [8626, 'Caymus'],
#  [999997365, 'Moss Roxx'],
#  [8626, 'Caymus'],
#  [8808, 'Duckhorn Vineyards'],
#  [999999028, 'Château Latour'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [5616, 'Tenuta Sette Ponti'],
#  [7746, 'Fattoria dei Barbi'],
#  [8798, 'Freemark Abbey'],
#  [999999692, 'Carruades de Lafite'],
#  [8220, 'La Rioja Alta'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [8693, 'Beaux Freres'],
#  [999999170, 'Chateau Petrus'],
#  [8966, 'Antinori'],
#  [999996940, 'Canvasback'],
#  [8623, 'Nickel & Nickel'],
#  [8509, 'Verite Estate'],
#  [999997962, 'Oakville Winery'],
#  [8382, 'Clarendon Hills'],
#  [999996814, 'Jamieson Ranch Vineyards'],
#  [999999167, 'Chateau Montrose'],
#  [8341, 'Hahn Winery'],
#  [8626, 'Caymus'],
#  [8485, 'Jordan Vineyard & Winery'],
#  [999998509, 'Benanti'],
#  [999999170, 'Chateau Petrus'],
#  [999998003, 'Bibi Graetz'],
#  [999999170, 'Chateau Petrus'],
#  [8509, 'Verite Estate'],
#  [5917, 'Chateau Pontet-Canet'],
#  [999999130, "Chateau Cos d'Estournel"],
#  [999999160, 'Chateau Lafite Rothschild'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [999997859, 'Mt. Brave'],
#  [8469, 'Clos du Val'],
#  [8844, 'Robert Mondavi Winery'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999999159, 'Chateau Lafleur'],
#  [999999161, 'Chateau Lynch-Bages'],
#  [999999169, 'Chateau Mouton Rothschild'],
#  [999995860, 'Chateau Peymouton'],
#  [8101, 'CVNE'],
#  [999998220, 'Greywacke'],
#  [999997499, 'The Prisoner Wine Company'],
#  [8008, 'Schug Estate Winery'],
#  [8210, 'Castello di Monsanto'],
#  [8061, 'Gaja'],
#  [999999171, 'Chateau Pavie'],
#  [8469, 'Clos du Val'],
#  [8794, "Frog's Leap"],
#  [6048, 'Joel Gott'],
#  [999996970, 'Chateau Mayne Vieil'],
#  [8231, 'Borgo Scopeto'],
#  [999997909, 'Lucky'],
#  [999998771, 'Antica'],
#  [6554, 'Vieux Chateau Certan'],
#  [8061, 'Gaja'],
#  [5616, 'Tenuta Sette Ponti'],
#  [8894, 'Frescobaldi'],
#  [6449, 'Robert Stemmler'],
#  [6396, 'Clos des Papes'],
#  [999996787, 'Trombetta'],
#  [999996819, 'Chapter 24'],
#  [8337, 'Rombauer Vineyards'],
#  [8794, "Frog's Leap"],
#  [5997, 'Faust'],
#  [6024, 'Haras de Pirque'],
#  [999996026, 'Baron de Ley'],
#  [8963, 'Concha y Toro'],
#  [8788, 'Kendall-Jackson'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [8382, 'Clarendon Hills'],
#  [7372, 'Il Poggione'],
#  [8754, "Stag's Leap Wine Cellars"],
#  [8233, 'Domaine Drouhin Oregon'],
#  [999998393, 'CADE Winery'],
#  [999999478, 'Roots Run Deep'],
#  [8660, 'Bodegas Muga'],
#  [8677, 'Chappellet Winery'],
#  [5370, 'Miura Vineyards'],
#  [8660, 'Bodegas Muga'],
#  [999998393, 'CADE Winery'],
#  [7069, 'Meo-Camuzet'],
#  [8834, "Stags' Leap Winery"],
#  [8754, "Stag's Leap Wine Cellars"],
#  [999998126, 'Black Stallion Winery'],
#  [999999768, 'Donatella Cinelli Colombini'],
#  [6307, 'Treana Winery'],
#  [5257, 'Fattoria di Felsina'],
#  [5388, 'Flowers'],
#  [999997354, 'Rafael Reverte'],
#  [5257, 'Fattoria di Felsina'],
#  [8762, 'Seghesio Family Vineyards'],
#  [5714, 'Benjamin Romeo'],
#  [999999704, 'Mendel'],
#  [6623, 'Smith & Hook Winery'],
#  [8491, 'Col Solare'],
#  [999994608, 'Masseto'],
#  [999999718, 'K Vintners'],
#  [8777, 'Faustino'],
#  [999996198, 'Le Potazzine'],
#  [999994832, 'Renzo Marinai'],
#  [999996970, 'Chateau Mayne Vieil'],
#  [999996472, 'William Harrison'],
#  [999999153, 'Chateau Cheval Blanc'],
#  [999999528, 'Klinker Brick'],
#  [8299, 'La Gerla'],
#  [8857, 'M. Chapoutier'],
#  [8853, 'Columbia Crest'],
#  [999997417, 'Meiomi'],
#  [9711, 'Frank Family Vineyards'],
#  [999998277, 'Robert Hall'],
#  [8634, 'Far Niente'],
#  [999996953, 'Orin Swift Cellars'],
#  [7763, 'Chateau Les-Charmes Godard'],
#  [10026, 'Domaine Saint Prefert'],
#  [999999529, 'Ghost Block'],
#  [6169, 'Inglenook'],
#  [999994845, 'Intrinsic'],
#  [8345, 'Ridge'],
#  [8716, 'Adelsheim'],
#  [7071, 'Barnett Vineyards'],
#  [8662, 'Abadia Retuerta'],
#  [8518, 'Cakebread'],
#  [999999164, 'Chateau Margaux'],
#  [8626, 'Caymus'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [999998208, 'Sur de los Andes'],
#  [8887, 'Groth Vineyards & Winery'],
#  [8705, 'Bernardus'],
#  [8035, 'Chateau La Cardonne'],
#  [8575, 'Atlas Peak Winery'],
#  [8101, 'CVNE'],
#  [999999169, 'Chateau Mouton Rothschild'],
#  [999999678, 'Substance'],
#  [999999173, 'Chateau Pichon-Longueville Baron'],
#  [8407, 'G.D. Vajra'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [8070, 'Almaviva'],
#  [7960, 'Domus Aurea'],
#  [999994818, 'Farnetella'],
#  [999998601, 'Domaine de Cristia'],
#  [8382, 'Clarendon Hills'],
#  [8759, 'Lapostolle'],
#  [999995114, 'Xavier Vins'],
#  [999999131, 'Chateau Clerc Milon'],
#  [5916, 'Chateau Montelena'],
#  [6191, 'Shafer Vineyards'],
#  [999998234, 'Ritual'],
#  [999999037, 'Mount Veeder Winery'],
#  [8101, 'CVNE'],
#  [999996113, 'Department 66'],
#  [8534, 'Jean-Louis Chave '],
#  [8762, 'Seghesio Family Vineyards'],
#  [999999173, 'Chateau Pichon-Longueville Baron'],
#  [8657, 'Guigal'],
#  [8225, 'Caparzo'],
#  [7847, 'Produttori del Barbaresco'],
#  [6019, 'Hall'],
#  [999997585, 'Reata'],
#  [8800, 'Franciscan Estate'],
#  [999995136, 'Chateau le Doyenne'],
#  [999996570, 'Noiro'],
#  [7847, 'Produttori del Barbaresco'],
#  [999998938, 'Domenico Clerico'],
#  [8728, 'Yalumba'],
#  [6351, 'Tikal'],
#  [6562, 'Giacomo Mori'],
#  [999999578, 'MooBuzz'],
#  [8657, 'Guigal'],
#  [6359, 'Sella & Mosca'],
#  [8503, 'J. Bookwalter'],
#  [8176, 'Belle Glos'],
#  [6998, 'Valdicava'],
#  [999999649, 'The Donum Estate'],
#  [999998723, 'Lucienne'],
#  [6403, 'Ringbolt'],
#  [999997989, 'DAOU Vineyards'],
#  [10660, 'Domaine Ponsot'],
#  [999996953, 'Orin Swift Cellars'],
#  [5916, 'Chateau Montelena'],
#  [999997499, 'The Prisoner Wine Company'],
#  [5616, 'Tenuta Sette Ponti'],
#  [999999165, 'Chateau Pape Clement'],
#  [999998524, 'Decoy'],
#  [8866, 'Beringer Vineyards'],
#  [8407, 'G.D. Vajra'],
#  [8527, 'Diamond Creek'],
#  [999999045, "Chateau L'Evangile"],
#  [8623, 'Nickel & Nickel'],
#  [999999035, 'Scarecrow'],
#  [8934, 'Condado de Haza'],
#  [8285, 'Zenato'],
#  [8816, 'Calera'],
#  [7906, 'Le Macchiole'],
#  [8348, 'Paul Hobbs'],
#  [8951, 'Marques de Murrieta'],
#  [8233, 'Domaine Drouhin Oregon'],
#  [8808, 'Duckhorn Vineyards'],
#  [6436, 'Goldeneye'],
#  [999996743, 'Monteverro'],
#  [999996929, 'Chateau Baret'],
#  [999996206, 'Flying Goat Cellars'],
#  [999998321, 'Hourglass'],
#  [8061, 'Gaja'],
#  [5773, 'Cayuse'],
#  [8656, 'Leeuwin Estate'],
#  [999997130, 'Locations by Dave Phinney'],
#  [8220, 'La Rioja Alta'],
#  [8073, 'Dominus'],
#  [5388, 'Flowers'],
#  [999996472, 'William Harrison'],
#  [999998295, 'Leviathan'],
#  [8095, 'Luca'],
#  [8143, 'Chateau Teyssier'],
#  [5773, 'Cayuse'],
#  [999998917, 'Stoller Vineyards'],
#  [999999757, 'Ramey'],
#  [999994725, 'Daniel Cohn'],
#  [7449, 'Chimney Rock Winery'],
#  [6257, 'Yangarra Estate'],
#  [999995988, 'Chateau Hanteillan'],
#  [9728, 'Castiglion del Bosco'],
#  [999995410, 'Marcelo Pelleriti'],
#  [8784, 'St. Francis Winery'],
#  [8844, 'Robert Mondavi Winery'],
#  [6436, 'Goldeneye'],
#  [8699, 'St. Supery Estate Vineyard & Winery'],
#  [8866, 'Beringer Vineyards'],
#  [7839, 'Vina Carmen'],
#  [999999524, 'Saxum'],
#  [8820, 'Bogle Vineyards'],
#  [999999661, 'Penner-Ash'],
#  [999999156, 'Chateau Grand-Puy-Lacoste'],
#  [999998889, 'J Vineyards & Winery'],
#  [5916, 'Chateau Montelena'],
#  [10660, 'Domaine Ponsot'],
#  [8493, 'Rex Hill'],
#  [9802, 'Ventana'],
#  [8629, 'The Hess Collection'],
#  [999999608, 'M. Marengo'],
#  [999996904, 'Noble Vines '],
#  [999999760, 'Bodegas Ateca'],
#  [8907, 'Beaulieu Vineyard'],
#  [999999918, 'Michael David Winery'],
#  [6552, 'Chateau Pavie Macquin'],
#  [5572, 'MacMurray Ranch'],
#  [999996819, 'Chapter 24'],
#  [5913, 'Chateau Leoville Poyferre'],
#  [999997190, 'Dugat-Py'],
#  [8527, 'Diamond Creek'],
#  [8533, 'Woodward Canyon'],
#  [8345, 'Ridge'],
#  [999998524, 'Decoy'],
#  [8844, 'Robert Mondavi Winery'],
#  [8808, 'Duckhorn Vineyards'],
#  [7972, 'Wirra Wirra'],
#  [8148, 'Chateau Lyonnat'],
#  [8754, "Stag's Leap Wine Cellars"],
#  [8754, "Stag's Leap Wine Cellars"],
#  [999999525, 'Marcassin'],
#  [8748, 'Trefethen Vineyards'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [999997989, 'DAOU Vineyards'],
#  [10518, 'Siduri'],
#  [8073, 'Dominus'],
#  [7989, 'Allegrini'],
#  [999999169, 'Chateau Mouton Rothschild'],
#  [8340, 'Honig Vineyard & Winery'],
#  [8634, 'Far Niente'],
#  [6019, 'Hall'],
#  [8517, 'Sequoia Grove Vineyards'],
#  [8762, 'Seghesio Family Vineyards'],
#  [6568, 'Domaine Lafage'],
#  [7906, 'Le Macchiole'],
#  [999997041, 'Levet'],
#  [999998737, 'Doubleback'],
#  [7062, 'Joseph Swan'],
#  [8701, 'Justin'],
#  [999996920, 'Line 39'],
#  [8701, 'Justin'],
#  [8692, "d'Arenberg"],
#  [999999143, 'Chateau Malartic-Lagraviere'],
#  [999996958, 'Elouan'],
#  [8716, 'Adelsheim'],
#  [999999276, 'B Side'],
#  [8382, 'Clarendon Hills'],
#  [8688, 'Los Vascos'],
#  [999999038, 'Chateau Rauzan-Segla'],
#  [5917, 'Chateau Pontet-Canet'],
#  [999999529, 'Ghost Block'],
#  [8335, 'Ojai'],
#  [8726, 'Conundrum'],
#  [7821, 'Pepperwood Grove'],
#  [7811, 'Trentadue'],
#  [6084, 'Luigi Bosca'],
#  [6359, 'Sella & Mosca'],
#  [10138, 'Conti Costanti'],
#  [6513, 'Piedrasassi'],
#  [8966, 'Antinori'],
#  [999998234, 'Ritual'],
#  [999997481, 'Il Palagio'],
#  [8951, 'Marques de Murrieta'],
#  [8966, 'Antinori'],
#  [999997986, 'Giacomo Conterno'],
#  [5917, 'Chateau Pontet-Canet'],
#  [8804, 'Monte Antico'],
#  [999999127, 'Chateau Duhart-Milon'],
#  [999996314, 'Scribe'],
#  [8964, 'Castello Banfi'],
#  [8534, 'Jean-Louis Chave '],
#  [999995089, 'Clos des Fous'],
#  [5432, 'Tenuta San Guido'],
#  [8061, 'Gaja'],
#  [999996498, 'Chateau Franc Mayne'],
#  [8560, 'William Hill Winery'],
#  [999999132, 'Chateau Gazin'],
#  [8466, 'Mayacamas'],
#  [8912, 'Buena Vista Winery'],
#  [8869, 'Alexander Valley Vineyards'],
#  [7364, 'Tapiz'],
#  [999995466, 'Resonance'],
#  [999999573, 'Statti'],
#  [8008, 'Schug Estate Winery'],
#  [7349, 'Chateau Malescot St. Exupery'],
#  [999998938, 'Domenico Clerico'],
#  [999997130, 'Locations by Dave Phinney'],
#  [5973, 'Domaine des Lambrays'],
#  [8575, 'Atlas Peak Winery'],
#  [8693, 'Beaux Freres'],
#  [999997258, 'Wild Ridge'],
#  [999998208, 'Sur de los Andes'],
#  [8010, 'Patricia Green'],
#  [999998448, 'Clarendelle'],
#  [6572, 'Oberon'],
#  [999996373, 'Chateau de Vaudieu'],
#  [999999319, 'Bodega Noemia de Patagonia'],
#  [999998478, 'Corliss'],
#  [7528, 'PlumpJack Winery'],
#  [999999160, 'Chateau Lafite Rothschild'],
#  [999997989, 'DAOU Vineyards'],
#  [8185, 'Staglin Family Vineyard'],
#  [8657, 'Guigal'],
#  [9284, 'Chateau du Cartillon'],
#  [999998091, 'Le Dome'],
#  [5773, 'Cayuse'],
#  [999995237, 'Nicolas-Jay'],
#  [8834, "Stags' Leap Winery"],
#  [6345, 'Bodegas El Nido'],
#  [8341, 'Hahn Winery'],
#  [8866, 'Beringer Vineyards'],
#  [8182, 'Argyle'],
#  [8657, 'Guigal'],
#  [999997499, 'The Prisoner Wine Company'],
#  [999998888, 'Acrobat'],
#  [8754, "Stag's Leap Wine Cellars"],
#  [8754, "Stag's Leap Wine Cellars"],
#  [8382, 'Clarendon Hills'],
#  [6695, 'Domaine du Vieux Telegraphe'],
#  [999999130, "Chateau Cos d'Estournel"],
#  [999998662, 'Capanna'],
#  [999998958, 'Hartford'],
#  [999998374, 'Josh Cellars'],
#  [8794, "Frog's Leap"],
#  [5562, 'Dry Creek Vineyard'],
#  [8816, 'Calera'],
#  [8903, 'Penfolds Wines'],
#  [8679, 'Fess Parker'],
#  [6040, "Jacob's Creek"],
#  [8657, 'Guigal'],
#  [8348, 'Paul Hobbs'],
#  [999997130, 'Locations by Dave Phinney'],
#  [6105, 'Mollydooker'],
#  [999999918, 'Michael David Winery'],
#  [999999161, 'Chateau Lynch-Bages'],
#  [7712, 'Vietti'],
#  [8100, 'Darioush'],
#  [8963, 'Concha y Toro'],
#  [8111, "L'Ecole 41"],
#  [999997856, 'Philip Mazzei'],
#  [8511, 'Atalon'],
#  [8651, 'Louis Bernard'],
#  [999999430, 'Blackbird Vineyards'],
#  [999997991, 'Cherry Pie'],
#  [999997905, 'Formidable'],
#  [999997692, 'Hoopes Vineyard'],
#  [7837, "Tenuta dell'Ornellaia"],
#  [5309, 'Castello dei Rampolla'],
#  [999997855, 'Francis Ford Coppola Winery'],
#  [8576, 'Willamette Valley Vineyards'],
#  [8769, 'Ravenswood'],
#  [8626, 'Caymus'],
#  [999999164, 'Chateau Margaux'],
#  [999997499, 'The Prisoner Wine Company'],
#  [999999769, 'Tolaini'],
#  [999996692, 'Mercer Canyons'],
#  [5252, 'Parducci'],
#  [8839, 'Ruffino'],
#  [6491, 'Fattoria del Cerro'],
#  [8527, 'Diamond Creek'],
#  [5681, 'Trinchero Napa Valley'],
#  [8407, 'G.D. Vajra'],
#  [10518, 'Siduri'],
#  [8935, 'Marques de Caceres'],
#  [6663, 'Storrs'],
#  [999999416, 'Hidden Ridge'],
#  [9097, 'Brooks'],
#  [10520, 'Marques del Puerto'],
#  [8252, 'Melville'],
#  [8701, 'Justin'],
#  [8047, 'Marchesi di Barolo'],
#  [8622, 'Chateau de Beaucastel'],
#  [999997354, 'Rafael Reverte'],
#  [7847, 'Produttori del Barbaresco'],
#  [8469, 'Clos du Val'],
#  [8484, 'Quintessa'],
#  [999996546, 'Peirson Meyer'],
#  [7071, 'Barnett Vineyards'],
#  [8926, 'Silverado Vineyards'],
#  [999996227, 'Chateau Francs Magnus'],
#  [999998869, 'Tilia'],
#  [999998522, 'Silver Oak Alexander Valley'],
#  [999995634, 'Diora'],
#  [8034, 'Ceretto'],
#  [6340, 'Paraduxx'],
#  [8352, 'Meerlust'],
#  [8808, 'Duckhorn Vineyards'],
#  [8452, 'Cardinale'],
#  [5920, 'Château Smith Haut Lafitte'],
#  [999997438, 'Livio Sassetti'],
#  [999997989, 'DAOU Vineyards'],
#  [999997499, 'The Prisoner Wine Company'],
#  [8095, 'Luca'],
#  [7069, 'Meo-Camuzet'],
#  [8176, 'Belle Glos'],
#  [8408, 'Montes'],
#  [5619, 'Campo Viejo'],
#  [8469, 'Clos du Val'],
#  [999996953, 'Orin Swift Cellars'],
#  [999996814, 'Jamieson Ranch Vineyards'],
#  [8699, 'St. Supery Estate Vineyard & Winery'],
#  [999997827, 'Mongeard Mugneret'],
#  [8382, 'Clarendon Hills'],
#  [999997052, 'Pali Wine Co'],
#  [6633, 'Poggio Antico'],
#  [7755, 'Domaine du Vieux Lazaret'],
#  [8370, 'Patz & Hall'],
#  [999995252, 'Love & Squalor'],
#  [8903, 'Penfolds Wines'],
#  [5309, 'Castello dei Rampolla'],
#  [8833, 'St. Clement Vineyards'],
#  [8469, 'Clos du Val'],
#  [5557, 'Lokoya'],
#  [7326, 'Aldo Conterno'],
#  [999998671, 'Altvs'],
#  [999998315, 'Apothic'],
#  [8061, 'Gaja'],
#  [999999918, 'Michael David Winery'],
#  [6420, 'Shoofly'],
#  [8881, 'Joseph Phelps Vineyards'],
#  [8415, 'Joseph Drouhin'],
#  [8967, 'Andrew Will Winery'],
#  [6365, 'Peju Province'],
#  [8760, 'Simi'],
#  [5432, 'Tenuta San Guido'],
#  [7513, 'Swanson'],
#  [8631, 'Dunn Vineyards'],
#  [999997438, 'Livio Sassetti'],
#  [8629, 'The Hess Collection'],
#  [999999847, 'Domaine Faiveley'],
#  [5605, 'Rochiolli'],
#  [5392, 'Cliff Lede Vineyards'],
#  [999997847, 'Hazana'],
#  [8907, 'Beaulieu Vineyard'],
#  [999998938, 'Domenico Clerico'],
#  [999995845, 'Marchesi Fumanelli'],
#  [8794, "Frog's Leap"],
#  [999997989, 'DAOU Vineyards'],
#  [8639, 'Neyers'],
#  [999999168, 'Chateau Monbousquet'],
#  [8912, 'Buena Vista Winery'],
#  [6435, 'Dog Point  Vineyard'],
#  [8363, 'Catena'],
#  [8225, 'Caparzo'],
#  [7906, 'Le Macchiole'],
#  [999999162, 'Chateau Leoville Barton'],
#  [8363, 'Catena'],
#  [8921, 'Ponzi'],
#  [7745, 'Fontanafredda'],
#  [8802, 'Ferrari-Carano'],
#  [6017, 'Gundlach Bundschu'],
#  [6906, 'Borgogno'],
#  [999999522, 'Sloan'],
#  [999995845, 'Marchesi Fumanelli'],
#  [999998029, 'Roger Sabon'],
#  [8513, 'Charles Krug'],
#  [7270, 'Pahlmeyer'],
#  [8657, 'Guigal'],
#  [7421, 'Araujo'],
#  [999999569, 'Cesari'],
#  [5768, 'Bodegas Caro'],
#  [8820, 'Bogle Vineyards'],
#  [999997070, 'The Crusher'],
#  [999999400, 'Vinedos Emiliana'],
#  [8518, 'Cakebread'],
#  [7861, 'Domaine de Beaurenard'],
#  [5517, 'Hewitt Vineyard'],
#  [7056, 'Bryant Family'],
#  [8853, 'Columbia Crest'],
#  [8304, 'Alamos'],
#  [8632, 'Cline'],
#  [8788, 'Kendall-Jackson'],
#  [6510, 'Damilano'],
#  [8230, 'Gary Farrell'],
#  [6559, 'Keenan'],
#  [999998477, 'Chateau La Grave'],
#  [5979, 'Domaines Barons de Rothschild'],
#  [999999017, 'Château Haut-Beausejour'],
#  [7075, 'Martinelli Winery & Vineyards'],
#  [5258, 'Domaine de Mourchon'],
#  [7755, 'Domaine du Vieux Lazaret'],
#  [6892, 'Tahbilk'],
#  [999998524, 'Decoy'],
#  [999998492, 'The Federalist'],
#  [999996580, 'Kinsella Estates'],
#  [8660, 'Bodegas Muga'],
#  [8966, 'Antinori'],
#  [999999755, 'Domaine de Saint Cosme'],
#  [8808, 'Duckhorn Vineyards'],
#  [8887, 'Groth Vineyards & Winery'],
#  [5773, 'Cayuse'],
#  [10810, 'Kosta Browne'],
#  [5495, 'Boekenhoutskloof'],
#  [8779, 'Luna Vineyards'],
#  [999996525, 'Boomtown by Dusted Valley'],
#  [5985, 'Don Rodolfo'],
#  [999999837, 'Chateau Labegorce'],
#  [999995747, 'WindRacer'],
#  [8569, 'Martin Ray'],
#  [5378, 'Kaiken'],
#  [999998523, 'Migration'],
#  [999998082, 'Jonata'],
#  [999998691, 'A.P. Vin'],
#  [999999688, 'Domaine Laroque'],
#  [999998391, 'Pennywise'],
#  [6049, 'John Duval'],
#  [8800, 'Franciscan Estate'],
#  [999994764, 'Tank Garage Winery'],
#  [7321, 'Emmolo'],
#  [6538, 'St. Innocent Winery'],
#  [5452, 'Farnese'],
#  [5650, 'Arboleda'],
#  [8835, 'Chateau Ste. Michelle'],
#  [999998299, 'La Serena'],
#  [999999165, 'Chateau Pape Clement'],
#  [8662, 'Abadia Retuerta'],
#  [8111, "L'Ecole 41"],
#  [999996218, 'Domaine La Barroche'],
#  [8220, 'La Rioja Alta'],
#  [8074, 'Sterling Vineyards'],
#  [5916, 'Chateau Montelena'],
#  [999998548, 'Crossbarn by Paul Hobbs'],
#  [8759, 'Lapostolle'],
#  [6024, 'Haras de Pirque'],
#  [999999881, 'Bruno Giacosa'],
#  [999999030, 'Chateau Larose-Trintaudon'],
#  [8820, 'Bogle Vineyards'],
#  [999996577, 'Opolo'],
#  [8967, 'Andrew Will Winery'],
#  [999999879, 'Wine Spots'],
#  [8460, 'Flora Springs'],
#  [999999526, 'Charles Smith'],
#  [999999166, 'Chateau Palmer'],
#  [999998862, 'RouteStock'],
#  [8744, 'J. Lohr Winery'],
#  [999995959, 'Real Companhia Velha'],
#  [999996352, 'POE'],
#  [8760, 'Simi'],
#  [7129, 'Rodano'],
#  [999999749, 'Finca Decero'],
#  [10518, 'Siduri'],
#  [8903, 'Penfolds Wines'],
#  [6175, 'Bodegas Salentein'],
#  [999999744, "Terra d'Oro"],
#  [8906, 'Grgich Hills Cellar'],
#  [999998002, 'DuMOL'],
#  [999997224, "Maison L'Envoye"],
#  [999998591, 'Fattoria Viticcio'],
#  [999998887, 'Orma'],
#  [8613, 'Bodega Norton'],
#  [999997991, 'Cherry Pie'],
#  [8356, 'Archery Summit Winery'],
#  [999997227, 'Alpha Omega'],
#  [7074, 'Cornerstone Cellars'],
#  [5932, 'Clos Fourtet'],
#  [8344, 'Chalone Vineyard'],
#  [999998818, 'Rocca di Frassinello'],
#  [7913, 'Il Marroneto'],
#  [999996531, 'Voliero'],
#  [6832, 'Zaccagnini'],
#  [999996075, 'Marichal'],
#  [8762, 'Seghesio Family Vineyards'],
#  [999998949, 'Soter Vineyards'],
#  [8721, 'Bouchard Pere & Fils'],
#  [8094, 'Mastrojanni'],
#  [999999216, 'Ladera'],
#  [999997551, 'Joseph Jewell'],
#  [8907, 'Beaulieu Vineyard'],
#  [5572, 'MacMurray Ranch'],
#  [999998708, 'Michel Gassier'],
#  [999999165, 'Chateau Pape Clement'],
#  [5772, 'Castle Rock Winery'],
#  ...]

# %% [markdown]
# Just a quick note: The order appears to be the same, so I can use offset to systematically get the data.
# Another note: I should check area once I'm done. I see a lot of None's.

# %% [markdown]
# Now to turn these into DataFrames. Here is where I'll remove duplicates.

# %%
main_wines_cols = ['Wine ID',
                   'Wine name',
                   'Vintage',
                   'Score',
                   'Vineyard ID',
                   'Varietal ID',
                   'Wine Type ID',
                   'Appellation ID',
                   'Region ID',
                   'Area ID']

# %%
main_wines_db = pd.DataFrame(main_wines, columns=main_wines_cols)
main_wines_db = main_wines_db.drop_duplicates()

# %%
main_wines_db.head()
# Out:
#    Wine ID                                          Wine name Vintage  Score  \
# 0   142049         Pahlmeyer Napa Valley Proprietary Red 2013    2013     96
# 1   153157     Silver Oak Napa Valley Cabernet Sauvignon 2011    2011     91
# 2   154691  Haras de Pirque Hussonet Gran Reserva Cabernet...    2011     95
# 3   155466                        Joseph Phelps Insignia 2013    2013    100
# 4   158048   The Debate Three Vineyard Collection 3-pack 2012    2012    100
#
#    Vineyard ID  Varietal ID  Wine Type ID  Appellation ID  Region ID Area ID
# 0         7270          144           124            2398        101    None
# 1         7396          139           124            2398        101    None
# 2         6024          139           124            2428        112    None
# 3         8881          144           124            2398        101    None
# 4    999997220          139           124            2398        101    None

# %%
varietals_cols = ['Varietal ID', 'Varietal Name', 'Varietal URL']

# %%
varietals_db = pd.DataFrame(varietals, columns=varietals_cols)
varietals_db = varietals_db.drop_duplicates()

# %%
varietals_db
# Out:
#      Varietal ID        Varietal Name  \
# 0            144  Bordeaux Red Blends
# 1            139   Cabernet Sauvignon
# 8            141            Zinfandel
# 13           145     Other Red Blends
# 14           163           Sangiovese
# 17           169          Tempranillo
# 19           143           Pinot Noir
# 24           138               Merlot
# 26           146         Syrah/Shiraz
# 68         10082     Rhone Red Blends
# 98         10080             Grenache
# 102        10079               Malbec
# 144          170             Nebbiolo
# 200          195       Other Red Wine
# 202          197       Cabernet Franc
# 355          176         Petite Sirah
# 559        10081            Carmenere
# 591          172              Barbera
# 683        10086         Nero d'Avola
# 754          150                Gamay
#
#                                           Varietal URL
# 0    http://www.wine.com/v6/Bordeaux-Red-Blends/win...
# 1    http://www.wine.com/v6/Cabernet-Sauvignon/wine...
# 8    http://www.wine.com/v6/Zinfandel/wine/list.asp...
# 13   http://www.wine.com/v6/Other-Red-Blends/wine/l...
# 14   http://www.wine.com/v6/Sangiovese/wine/list.as...
# 17   http://www.wine.com/v6/Tempranillo/wine/list.a...
# 19   http://www.wine.com/v6/Pinot-Noir/wine/list.as...
# 24   http://www.wine.com/v6/Merlot/wine/list.aspx?N...
# 26   http://www.wine.com/v6/SyrahShiraz/wine/list.a...
# 68   http://www.wine.com/v6/Rhone-Red-Blends/wine/l...
# 98   http://www.wine.com/v6/Grenache/wine/list.aspx...
# 102  http://www.wine.com/v6/Malbec/wine/list.aspx?N...
# 144  http://www.wine.com/v6/Nebbiolo/wine/list.aspx...
# 200  http://www.wine.com/v6/Other-Red-Wine/wine/lis...
# 202  http://www.wine.com/v6/Cabernet-Franc/wine/lis...
# 355  http://www.wine.com/v6/Petite-Sirah/wine/list....
# 559  http://www.wine.com/v6/Carmenere/wine/list.asp...
# 591  http://www.wine.com/v6/Barbera/wine/list.aspx?...
# 683  http://www.wine.com/v6/Nero-dAvola/wine/list.a...
# 754  http://www.wine.com/v6/Gamay/wine/list.aspx?N=...

# %%
wine_types_cols = ['Wine Type ID', 'Wine Type Name', 'Wine Type URL']

# %%
wine_types_db = pd.DataFrame(wine_types, columns=wine_types_cols)
wine_types_db = wine_types_db.drop_duplicates()

# %%
wine_types_db
# Out:
#    Wine Type ID Wine Type Name  \
# 0           124      Red Wines
#
#                                        Wine Type URL
# 0  http://www.wine.com/v6/Red-Wines/wine/list.asp...

# %% [markdown]
# Remember that red wines was in the search query.

# %%
appellations_cols = ['Appellation ID', 'Appellation Name']

# %%
appellations_db = pd.DataFrame(appellations, columns=appellations_cols)
appellations_db = appellations_db.drop_duplicates()

# %%
appellations_db.head()
# Out:
#    Appellation ID  Appellation Name
# 0            2398       Napa Valley
# 2            2428             Chile
# 5            2371     Sonoma County
# 6           10049          Pauillac
# 8            2388  Other California

# %%
regions_cols = ['Region ID', 'Region Name']

# %%
regions_db = pd.DataFrame(regions, columns=regions_cols)
regions_db = regions_db.drop_duplicates()

# %%
regions_db
# Out:
#       Region ID             Region Name
# 0           101              California
# 2           112           South America
# 6         10038       France - Bordeaux
# 13          105                   Italy
# 17          109                   Spain
# 19          103                  Oregon
# 22          104              Washington
# 26          108               Australia
# 50          114             New Zealand
# 68        10039          France - Rhone
# 90          102  France - Other regions
# 433         113            South Africa
# 583         107                Portugal
# 608 -2147483648
# 829         115                  Greece

# %%
areas_cols = ['Areas ID', 'Areas Name']

# %%
areas_db = pd.DataFrame(areas, columns=areas_cols)
areas_db = areas_db.drop_duplicates()

# %%
areas_db
# Out:
# Empty DataFrame
# Columns: [Areas ID, Areas Name]
# Index: []

# %% [markdown]
# So, currently, there is no area data.

# %%
vineyards_cols = ['Vineyard ID', 'Vineyard Name']

# %%
vineyards_db = pd.DataFrame(vineyards, columns=vineyards_cols)
vineyards_db = vineyards_db.drop_duplicates()

# %%
vineyards_db.head()
# Out:
#    Vineyard ID            Vineyard Name
# 0         7270                Pahlmeyer
# 1         7396   Silver Oak Napa Valley
# 2         6024          Haras de Pirque
# 3         8881  Joseph Phelps Vineyards
# 4    999997220               The Debate

# %% [markdown]
# I'm going to forget about the area code. It seems empty most of the time, so I'll forget about it.

# %%
payload_test = {'filter': 'product(153157)', 'apikey': creds['KEY']}

# %%
r_prod = requests.get(url_string, params=payload_test)

# %%
data_prod = json.loads(r_prod.text)

# %%
data_prod['Products']['List'][0]['Community']['Reviews']['Url']
# Out:
# 'http://www.wine.com/v6/Silver-Oak-Napa-Valley-Cabernet-Sauvignon-2011/wine/153157/Detail.aspx?pageType=reviews'
